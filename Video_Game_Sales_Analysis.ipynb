# %% [markdown]
# # VIDEO GAME SALES ANALYSIS USING SQL

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# In this project, we are going to analyze video game sales using SQL. We'll be answering 10 different questions to discover the best-selling video games, the most popular publishers and platforms, the best-selling genre in a single year and so on.

# %% [markdown]
# The dataset can be found [here](https://www.kaggle.com/datasets/gregorut/videogamesales). It contains the sales of video games with their respective platforms from 1980 to 2020. The sales numbers represent the amount of copies sold in millions. Here are the 11 columns present in the dataset:

# %% [markdown]
# 1) Rank: Ranking of the game based on global sales.
# 2) Name: Video game title.
# 3) Platform: Platform the game was released on.
# 4) Year: Release year of the game.
# 5) Genre: Genre of the game.
# 6) Publisher: Publisher of the game.
# 7) NA_Sales: Sales in North America (copies sold in millions).
# 8) EU_Sales: Sales in Europe (copies sold in millions).
# 9) JP_Sales: Sales in Japan (copies sold in millions).
# 10) Other_Sales: Sales in the rest of the world (copies sold in millions).
# 11) Global_Sales: Total sales globally (copies sold in millions).

# %% [markdown]
# Let's first read the data.

# %%
import pandas as pd
df = pd.read_csv('vgsales.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %% [markdown]
# We will drop the rows that contain null values as well as the Rank column.

# %%
df = df.dropna().drop(columns='Rank')
df.shape
# Out:
# (16291, 10)

# %% [markdown]
# Now, we can export the dataset to our MySQL database. We'll then utilize the ipython-sql library to run SQL queries directly in this notebook.

# %%
import sqlalchemy
import pymysql

engine = sqlalchemy.create_engine(f'mysql+pymysql://root:{password}@localhost:3306/videogamesalesdb')
df.to_sql('vgsales', con=engine, index=False)
# Out:
# 16291

# %%
# %load_ext sql
# %sql mysql+pymysql://root:{password}@localhost:3306/videogamesalesdb
# Out:
# 'Connected: root@videogamesalesdb'

# %% [markdown]
# We'll also set the display limit to only 20 rows, to limit the amount of results displayed. So that when a query results in hundreds of rows, we won't have to scroll through everything.

# %%
# %config SqlMagic.displaylimit=20

# %% [markdown]
# &nbsp;

# %% [markdown]
# # QUESTIONS

# %% [markdown]
# #### 1. What are the top 10 best-selling video games globally?
# #### 2. What are the top 10 best-selling platforms and publishers globally?
# #### 3. Calculate the global sales for each genre. Display the count of each genre in the dataset as well as its percent total.
# #### 4. Determine the global sales per year. Compare it to the previous year.
# #### 5. Fetch the details of the top 5 best-selling games (with their respective platforms) for each genre.
# #### 6. What are the 5 best-selling games in North America and Europe?
# #### 7. What is the most popular genre in a single year?
# #### 8. What is the best-selling and worst-selling year for each publisher?
# #### 9. There are 12 different genres in total. Find the years that do not have all of them. What are those missing genres?
# #### 10. Out of the top 50 best-selling video games, what are the games that were released before 2000?

# %% [markdown]
# &nbsp;

# %% [markdown]
# ## 1. What are the top 10 best-selling video games globally?

# %%
# %%sql
#
# SELECT name, SUM(global_sales) AS global_sales
# FROM vgsales
# GROUP BY name
# ORDER BY global_sales DESC
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/videogamesalesdb
# 10 rows affected.
# [('Wii Sports', Decimal('82.74')),
#  ('Grand Theft Auto V', Decimal('55.92')),
#  ('Super Mario Bros.', Decimal('45.31')),
#  ('Tetris', Decimal('35.84')),
#  ('Mario Kart Wii', Decimal('35.82')),
#  ('Wii Sports Resort', Decimal('33.00')),
#  ('Pokemon Red/Pokemon Blue', Decimal('31.37')),
#  ('Call of Duty: Modern Warfare 3', Decimal('30.83')),
#  ('New Super Mario Bros.', Decimal('30.01')),
#  ('Call of Duty: Black Ops II', Decimal('29.72'))]

# %% [markdown]
# ## 2. What are the top 10 most popular platforms and publishers globally?

# %%
# %%sql
#
# SELECT platform, SUM(global_sales) AS global_sales
# FROM vgsales
# GROUP BY platform
# ORDER BY global_sales DESC
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/videogamesalesdb
# 10 rows affected.
# [('PS2', Decimal('1233.46')),
#  ('X360', Decimal('969.60')),
#  ('PS3', Decimal('949.35')),
#  ('Wii', Decimal('909.81')),
#  ('DS', Decimal('818.91')),
#  ('PS', Decimal('727.39')),
#  ('GBA', Decimal('305.62')),
#  ('PSP', Decimal('291.71')),
#  ('PS4', Decimal('278.10')),
#  ('PC', Decimal('254.70'))]

# %%
# %%sql
#
# SELECT publisher, SUM(global_sales) AS global_sales
# FROM vgsales
# GROUP BY publisher
# ORDER BY global_sales DESC
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/videogamesalesdb
# 10 rows affected.
# [('Nintendo', Decimal('1784.43')),
#  ('Electronic Arts', Decimal('1093.39')),
#  ('Activision', Decimal('721.41')),
#  ('Sony Computer Entertainment', Decimal('607.28')),
#  ('Ubisoft', Decimal('473.54')),
#  ('Take-Two Interactive', Decimal('399.30')),
#  ('THQ', Decimal('340.44')),
#  ('Konami Digital Entertainment', Decimal('278.56')),
#  ('Sega', Decimal('270.70')),
#  ('Namco Bandai Games', Decimal('253.65'))]

# %% [markdown]
# ## 3. Calculate the global sales for each genre. Display the count of each genre in the dataset as well as its percent total.

# %%
# %%sql
#
# SELECT genre, SUM(global_sales) AS global_sales, COUNT(genre) AS genre_count,
#        ROUND(COUNT(*)*100/(SELECT COUNT(*) FROM vgsales), 2) AS percent_total
# FROM vgsales
# GROUP BY genre
# ORDER BY 2 DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/videogamesalesdb
# 12 rows affected.
# [('Action', Decimal('1722.84'), 3251, Decimal('19.96')),
#  ('Sports', Decimal('1309.24'), 2304, Decimal('14.14')),
#  ('Shooter', Decimal('1026.20'), 1282, Decimal('7.87')),
#  ('Role-Playing', Decimal('923.83'), 1470, Decimal('9.02')),
#  ('Platform', Decimal('829.13'), 875, Decimal('5.37')),
#  ('Misc', Decimal('789.87'), 1686, Decimal('10.35')),
#  ('Racing', Decimal('726.76'), 1225, Decimal('7.52')),
#  ('Fighting', Decimal('444.05'), 836, Decimal('5.13')),
#  ('Simulation', Decimal('389.98'), 848, Decimal('5.21')),
#  ('Puzzle', Decimal('242.21'), 570, Decimal('3.50')),
#  ('Adventure', Decimal('234.59'), 1274, Decimal('7.82')),
#  ('Strategy', Decimal('173.27'), 670, Decimal('4.11'))]

# %% [markdown]
# ## 4. Determine the global sales per year. Compare it to the previous year.

# %%
# %%sql
#
# WITH cte AS (SELECT year, SUM(global_sales) AS global_sales
#              FROM vgsales
#              GROUP BY year
#              ORDER BY year)
# SELECT *, LAG(global_sales) OVER() AS prev_year_sales,
#        CASE WHEN global_sales > LAG(global_sales) OVER() THEN 'higher'
#             WHEN global_sales < LAG(global_sales) OVER() THEN 'lower'
#             END AS vs_prev_year
# FROM cte;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/videogamesalesdb
# 39 rows affected.
# [(1980, Decimal('11.38'), None, None),
#  (1981, Decimal('35.77'), Decimal('11.38'), 'higher'),
#  (1982, Decimal('28.86'), Decimal('35.77'), 'lower'),
#  (1983, Decimal('16.79'), Decimal('28.86'), 'lower'),
#  (1984, Decimal('50.36'), Decimal('16.79'), 'higher'),
#  (1985, Decimal('53.94'), Decimal('50.36'), 'higher'),
#  (1986, Decimal('37.07'), Decimal('53.94'), 'lower'),
#  (1987, Decimal('21.74'), Decimal('37.07'), 'lower'),
#  (1988, Decimal('47.22'), Decimal('21.74'), 'higher'),
#  (1989, Decimal('73.45'), Decimal('47.22'), 'higher'),
#  (1990, Decimal('49.39'), Decimal('73.45'), 'lower'),
#  (1991, Decimal('32.23'), Decimal('49.39'), 'lower'),
#  (1992, Decimal('76.16'), Decimal('32.23'), 'higher'),
#  (1993, Decimal('45.98'), Decimal('76.16'), 'lower'),
#  (1994, Decimal('79.17'), Decimal('45.98'), 'higher'),
#  (1995, Decimal('88.11'), Decimal('79.17'), 'higher'),
#  (1996, Decimal('199.15'), Decimal('88.11'), 'higher'),
#  (1997, Decimal('200.98'), Decimal('199.15'), 'higher'),
#  (1998, Decimal('256.47'), Decimal('200.98'), 'higher'),
#  (1999, Decimal('251.27'), Decimal('256.47'), 'lower'),
#  (2000, Decimal('201.56'), Decimal('251.27'), 'lower'),
#  (2001, Decimal('331.47'), Decimal('201.56'), 'higher'),
#  (2002, Decimal('395.52'), Decimal('331.47'), 'higher'),
#  (2003, Decimal('357.85'), Decimal('395.52'), 'lower'),
#  (2004, Decimal('414.01'), Decimal('357.85'), 'higher'),
#  (2005, Decimal('458.51'), Decimal('414.01'), 'higher'),
#  (2006, Decimal('521.04'), Decimal('458.51'), 'higher'),
#  (2007, Decimal('609.92'), Decimal('521.04'), 'higher'),
#  (2008, Decimal('678.90'), Decimal('609.92'), 'higher'),
#  (2009, Decimal('667.30'), Decimal('678.90'), 'lower'),
#  (2010, Decimal('600.29'), Decimal('667.30'), 'lower'),
#  (2011, Decimal('515.80'), Decimal('600.29'), 'lower'),
#  (2012, Decimal('363.49'), Decimal('515.80'), 'lower'),
#  (2013, Decimal('368.11'), Decimal('363.49'), 'higher'),
#  (2014, Decimal('337.03'), Decimal('368.11'), 'lower'),
#  (2015, Decimal('264.44'), Decimal('337.03'), 'lower'),
#  (2016, Decimal('70.90'), Decimal('264.44'), 'lower'),
#  (2017, Decimal('0.05'), Decimal('70.90'), 'lower'),
#  (2020, Decimal('0.29'), Decimal('0.05'), 'higher')]

# %% [markdown]
# ## 5. Fetch the details of the top 5 best-selling games (with their respective platforms) for each genre.

# %%
# %%sql
#
# WITH cte AS (SELECT *, DENSE_RANK() OVER(PARTITION BY genre ORDER BY global_sales DESC) AS rnk
#              FROM vgsales)
# SELECT *
# FROM cte
# WHERE rnk < 6;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/videogamesalesdb
# 60 rows affected.
# [('Grand Theft Auto V', 'PS3', 2013, 'Action', 'Take-Two Interactive', Decimal('7.01'), Decimal('9.27'), Decimal('0.97'), Decimal('4.14'), Decimal('21.40'), 1),
#  ('Grand Theft Auto: San Andreas', 'PS2', 2004, 'Action', 'Take-Two Interactive', Decimal('9.43'), Decimal('0.40'), Decimal('0.41'), Decimal('10.57'), Decimal('20.81'), 2),
#  ('Grand Theft Auto V', 'X360', 2013, 'Action', 'Take-Two Interactive', Decimal('9.63'), Decimal('5.31'), Decimal('0.06'), Decimal('1.38'), Decimal('16.38'), 3),
#  ('Grand Theft Auto: Vice City', 'PS2', 2002, 'Action', 'Take-Two Interactive', Decimal('8.41'), Decimal('5.49'), Decimal('0.47'), Decimal('1.78'), Decimal('16.15'), 4),
#  ('Grand Theft Auto III', 'PS2', 2001, 'Action', 'Take-Two Interactive', Decimal('6.99'), Decimal('4.51'), Decimal('0.30'), Decimal('1.30'), Decimal('13.10'), 5),
#  ('Super Mario Land 2: 6 Golden Coins', 'GB', 1992, 'Adventure', 'Nintendo', Decimal('6.16'), Decimal('2.04'), Decimal('2.69'), Decimal('0.29'), Decimal('11.18'), 1),
#  ("Assassin's Creed", 'X360', 2007, 'Adventure', 'Ubisoft', Decimal('3.28'), Decimal('1.65'), Decimal('0.07'), Decimal('0.55'), Decimal('5.55'), 2),
#  ("Assassin's Creed", 'PS3', 2007, 'Adventure', 'Ubisoft', Decimal('1.91'), Decimal('2.00'), Decimal('0.09'), Decimal('0.83'), Decimal('4.83'), 3),
#  ('Zelda II: The Adventure of Link', 'NES', 1987, 'Adventure', 'Nintendo', Decimal('2.19'), Decimal('0.50'), Decimal('1.61'), Decimal('0.08'), Decimal('4.38'), 4),
#  ('Rugrats: Search For Reptar', 'PS', 1998, 'Adventure', 'THQ', Decimal('1.63'), Decimal('1.53'), Decimal('0.00'), Decimal('0.18'), Decimal('3.34'), 5),
#  ('Super Smash Bros. Brawl', 'Wii', 2008, 'Fighting', 'Nintendo', Decimal('6.75'), Decimal('2.61'), Decimal('2.66'), Decimal('1.02'), Decimal('13.04'), 1),
#  ('Super Smash Bros. for Wii U and 3DS', '3DS', 2014, 'Fighting', 'Nintendo', Decimal('3.24'), Decimal('1.35'), Decimal('2.42'), Decimal('0.43'), Decimal('7.45'), 2),
#  ('Tekken 3', 'PS', 1998, 'Fighting', 'Sony Computer Entertainment', Decimal('3.27'), Decimal('2.22'), Decimal('1.40'), Decimal('0.29'), Decimal('7.16'), 3),
#  ('Super Smash Bros. Melee', 'GC', 2001, 'Fighting', 'Nintendo', Decimal('4.41'), Decimal('1.04'), Decimal('1.39'), Decimal('0.22'), Decimal('7.07'), 4),
#  ('Street Fighter II: The World Warrior', 'SNES', 1992, 'Fighting', 'Capcom', Decimal('2.47'), Decimal('0.83'), Decimal('2.87'), Decimal('0.12'), Decimal('6.30'), 5),
#  ('Wii Play', 'Wii', 2006, 'Misc', 'Nintendo', Decimal('14.03'), Decimal('9.20'), Decimal('2.93'), Decimal('2.85'), Decimal('29.02'), 1),
#  ('Kinect Adventures!', 'X360', 2010, 'Misc', 'Microsoft Game Studios', Decimal('14.97'), Decimal('4.94'), Decimal('0.24'), Decimal('1.67'), Decimal('21.82'), 2),
#  ('Brain Age: Train Your Brain in Minutes a Day', 'DS', 2005, 'Misc', 'Nintendo', Decimal('4.75'), Decimal('9.26'), Decimal('4.16'), Decimal('2.05'), Decimal('20.22'), 3),
#  ('Just Dance 3', 'Wii', 2011, 'Misc', 'Ubisoft', Decimal('6.05'), Decimal('3.15'), Decimal('0.00'), Decimal('1.07'), Decimal('10.26'), 4),
#  ('Just Dance 2', 'Wii', 2010, 'Misc', 'Ubisoft', Decimal('5.84'), Decimal('2.89'), Decimal('0.01'), Decimal('0.78'), Decimal('9.52'), 5),
#  ('Super Mario Bros.', 'NES', 1985, 'Platform', 'Nintendo', Decimal('29.08'), Decimal('3.58'), Decimal('6.81'), Decimal('0.77'), Decimal('40.24'), 1),
#  ('New Super Mario Bros.', 'DS', 2006, 'Platform', 'Nintendo', Decimal('11.38'), Decimal('9.23'), Decimal('6.50'), Decimal('2.90'), Decimal('30.01'), 2),
#  ('New Super Mario Bros. Wii', 'Wii', 2009, 'Platform', 'Nintendo', Decimal('14.59'), Decimal('7.06'), Decimal('4.70'), Decimal('2.26'), Decimal('28.62'), 3),
#  ('Super Mario World', 'SNES', 1990, 'Platform', 'Nintendo', Decimal('12.78'), Decimal('3.75'), Decimal('3.54'), Decimal('0.55'), Decimal('20.61'), 4),
#  ('Super Mario Land', 'GB', 1989, 'Platform', 'Nintendo', Decimal('10.83'), Decimal('2.71'), Decimal('4.18'), Decimal('0.42'), Decimal('18.14'), 5),
#  ('Tetris', 'GB', 1989, 'Puzzle', 'Nintendo', Decimal('23.20'), Decimal('2.26'), Decimal('4.22'), Decimal('0.58'), Decimal('30.26'), 1),
#  ('Brain Age 2: More Training in Minutes a Day', 'DS', 2005, 'Puzzle', 'Nintendo', Decimal('3.44'), Decimal('5.36'), Decimal('5.32'), Decimal('1.18'), Decimal('15.30'), 2),
#  ('Pac-Man', '2600', 1982, 'Puzzle', 'Atari', Decimal('7.28'), Decimal('0.45'), Decimal('0.00'), Decimal('0.08'), Decimal('7.81'), 3),
#  ('Tetris', 'NES', 1988, 'Puzzle', 'Nintendo', Decimal('2.97'), Decimal('0.69'), Decimal('1.81'), Decimal('0.11'), Decimal('5.58'), 4),
#  ('Dr. Mario', 'GB', 1989, 'Puzzle', 'Nintendo', Decimal('2.18'), Decimal('0.96'), Decimal('2.00'), Decimal('0.20'), Decimal('5.34'), 5),
#  ('Mario Kart Wii', 'Wii', 2008, 'Racing', 'Nintendo', Decimal('15.85'), Decimal('12.88'), Decimal('3.79'), Decimal('3.31'), Decimal('35.82'), 1),
#  ('Mario Kart DS', 'DS', 2005, 'Racing', 'Nintendo', Decimal('9.81'), Decimal('7.57'), Decimal('4.13'), Decimal('1.92'), Decimal('23.42'), 2),
#  ('Gran Turismo 3: A-Spec', 'PS2', 2001, 'Racing', 'Sony Computer Entertainment', Decimal('6.85'), Decimal('5.09'), Decimal('1.87'), Decimal('1.16'), Decimal('14.98'), 3),
#  ('Mario Kart 7', '3DS', 2011, 'Racing', 'Nintendo', Decimal('4.74'), Decimal('3.91'), Decimal('2.67'), Decimal('0.89'), Decimal('12.21'), 4),
#  ('Gran Turismo 4', 'PS2', 2004, 'Racing', 'Sony Computer Entertainment', Decimal('3.01'), Decimal('0.01'), Decimal('1.10'), Decimal('7.53'), Decimal('11.66'), 5),
#  ('Pokemon Red/Pokemon Blue', 'GB', 1996, 'Role-Playing', 'Nintendo', Decimal('11.27'), Decimal('8.89'), Decimal('10.22'), Decimal('1.00'), Decimal('31.37'), 1),
#  ('Pokemon Gold/Pokemon Silver', 'GB', 1999, 'Role-Playing', 'Nintendo', Decimal('9.00'), Decimal('6.18'), Decimal('7.20'), Decimal('0.71'), Decimal('23.10'), 2),
#  ('Pokemon Diamond/Pokemon Pearl', 'DS', 2006, 'Role-Playing', 'Nintendo', Decimal('6.42'), Decimal('4.52'), Decimal('6.04'), Decimal('1.37'), Decimal('18.36'), 3),
#  ('Pokemon Ruby/Pokemon Sapphire', 'GBA', 2002, 'Role-Playing', 'Nintendo', Decimal('6.06'), Decimal('3.90'), Decimal('5.38'), Decimal('0.50'), Decimal('15.85'), 4),
#  ('Pokemon Black/Pokemon White', 'DS', 2010, 'Role-Playing', 'Nintendo', Decimal('5.57'), Decimal('3.28'), Decimal('5.65'), Decimal('0.82'), Decimal('15.32'), 5),
#  ('Duck Hunt', 'NES', 1984, 'Shooter', 'Nintendo', Decimal('26.93'), Decimal('0.63'), Decimal('0.28'), Decimal('0.47'), Decimal('28.31'), 1),
#  ('Call of Duty: Modern Warfare 3', 'X360', 2011, 'Shooter', 'Activision', Decimal('9.03'), Decimal('4.28'), Decimal('0.13'), Decimal('1.32'), Decimal('14.76'), 2),
#  ('Call of Duty: Black Ops', 'X360', 2010, 'Shooter', 'Activision', Decimal('9.67'), Decimal('3.73'), Decimal('0.11'), Decimal('1.13'), Decimal('14.64'), 3),
#  ('Call of Duty: Black Ops 3', 'PS4', 2015, 'Shooter', 'Activision', Decimal('5.77'), Decimal('5.81'), Decimal('0.35'), Decimal('2.31'), Decimal('14.24'), 4),
#  ('Call of Duty: Black Ops II', 'PS3', 2012, 'Shooter', 'Activision', Decimal('4.99'), Decimal('5.88'), Decimal('0.65'), Decimal('2.52'), Decimal('14.03'), 5),
#  ('Nintendogs', 'DS', 2005, 'Simulation', 'Nintendo', Decimal('9.07'), Decimal('11.00'), Decimal('1.93'), Decimal('2.75'), Decimal('24.76'), 1),
#  ('Animal Crossing: Wild World', 'DS', 2005, 'Simulation', 'Nintendo', Decimal('2.55'), Decimal('3.52'), Decimal('5.33'), Decimal('0.88'), Decimal('12.27'), 2),
#  ('Animal Crossing: New Leaf', '3DS', 2012, 'Simulation', 'Nintendo', Decimal('2.01'), Decimal('2.32'), Decimal('4.36'), Decimal('0.41'), Decimal('9.09'), 3),
#  ('The Sims 3', 'PC', 2009, 'Simulation', 'Electronic Arts', Decimal('0.98'), Decimal('6.42'), Decimal('0.00'), Decimal('0.71'), Decimal('8.11'), 4),
#  ('Cooking Mama', 'DS', 2006, 'Simulation', '505 Games', Decimal('3.13'), Decimal('1.94'), Decimal('0.07'), Decimal('0.58'), Decimal('5.72'), 5),
#  ('Wii Sports', 'Wii', 2006, 'Sports', 'Nintendo', Decimal('41.49'), Decimal('29.02'), Decimal('3.77'), Decimal('8.46'), Decimal('82.74'), 1),
#  ('Wii Sports Resort', 'Wii', 2009, 'Sports', 'Nintendo', Decimal('15.75'), Decimal('11.01'), Decimal('3.28'), Decimal('2.96'), Decimal('33.00'), 2),
#  ('Wii Fit', 'Wii', 2007, 'Sports', 'Nintendo', Decimal('8.94'), Decimal('8.03'), Decimal('3.60'), Decimal('2.15'), Decimal('22.72'), 3),
#  ('Wii Fit Plus', 'Wii', 2009, 'Sports', 'Nintendo', Decimal('9.09'), Decimal('8.59'), Decimal('2.53'), Decimal('1.79'), Decimal('22.00'), 4),
#  ('FIFA 16', 'PS4', 2015, 'Sports', 'Electronic Arts', Decimal('1.11'), Decimal('6.06'), Decimal('0.06'), Decimal('1.26'), Decimal('8.49'), 5),
#  ('Pokemon Stadium', 'N64', 1999, 'Strategy', 'Nintendo', Decimal('3.18'), Decimal('1.24'), Decimal('0.94'), Decimal('0.09'), Decimal('5.45'), 1),
#  ('Warzone 2100', 'PS', 1999, 'Strategy', 'Eidos Interactive', Decimal('2.79'), Decimal('1.89'), Decimal('0.00'), Decimal('0.33'), Decimal('5.01'), 2),
#  ('StarCraft II: Wings of Liberty', 'PC', 2010, 'Strategy', 'Activision', Decimal('2.56'), Decimal('1.68'), Decimal('0.00'), Decimal('0.59'), Decimal('4.83'), 3),
#  ('Warcraft II: Tides of Darkness', 'PC', 1995, 'Strategy', 'Activision', Decimal('1.70'), Decimal('2.27'), Decimal('0.00'), Decimal('0.23'), Decimal('4.21'), 4),
#  ('Pokémon Trading Card Game', 'GB', 1998, 'Strategy', 'Nintendo', Decimal('1.49'), Decimal('0.73'), Decimal('1.38'), Decimal('0.10'), Decimal('3.70'), 5)]

# %% [markdown]
# ## 6. What are the 5 best-selling games in North America and Europe?

# %%
# %%sql
#
# (SELECT name, SUM(na_sales) AS sales, 'NA' AS region
# FROM vgsales
# GROUP BY name
# ORDER BY sales DESC
# LIMIT 5)
# UNION
# (SELECT name, SUM(eu_sales) AS sales, 'EU' AS region
# FROM vgsales
# GROUP BY name
# ORDER BY sales DESC
# LIMIT 5);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/videogamesalesdb
# 10 rows affected.
# [('Wii Sports', Decimal('41.49'), 'NA'),
#  ('Super Mario Bros.', Decimal('32.48'), 'NA'),
#  ('Duck Hunt', Decimal('26.93'), 'NA'),
#  ('Tetris', Decimal('26.17'), 'NA'),
#  ('Grand Theft Auto V', Decimal('23.46'), 'NA'),
#  ('Wii Sports', Decimal('29.02'), 'EU'),
#  ('Grand Theft Auto V', Decimal('23.04'), 'EU'),
#  ('Mario Kart Wii', Decimal('12.88'), 'EU'),
#  ('FIFA 15', Decimal('12.40'), 'EU'),
#  ('Call of Duty: Modern Warfare 3', Decimal('11.29'), 'EU')]

# %% [markdown]
# ## 7. What is the most popular genre in a single year?

# %%
# %%sql
#
# SELECT genre, year, SUM(global_sales) AS global_sales
# FROM vgsales
# GROUP BY genre, year
# ORDER BY global_sales DESC
# LIMIT 1;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/videogamesalesdb
# 1 rows affected.
# [('Action', 2009, Decimal('139.36'))]

# %% [markdown]
# ## 8. What is the best-selling and worst-selling year for each publisher?

# %%
# %%sql
#
# WITH cte AS (SELECT publisher, year, SUM(global_sales) AS global_sales,
#                     MAX(SUM(global_sales)) OVER(PARTITION BY publisher) AS max_sales,
#                     MIN(SUM(global_sales)) OVER(PARTITION BY publisher) AS min_sales
#              FROM vgsales
#              GROUP BY publisher, year)
# SELECT publisher, year, global_sales,
#        CASE WHEN global_sales=max_sales AND global_sales=min_sales THEN 'both'
#             WHEN global_sales=max_sales THEN 'best'
#             WHEN global_sales=min_sales THEN 'worst'
#             END AS year_type
# FROM cte
# WHERE global_sales=max_sales OR global_sales=min_sales;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/videogamesalesdb
# 962 rows affected.
# [('10TACLE Studios', 2006, Decimal('0.02'), 'worst'),
#  ('10TACLE Studios', 2007, Decimal('0.09'), 'best'),
#  ('1C Company', 2009, Decimal('0.01'), 'worst'),
#  ('1C Company', 2011, Decimal('0.09'), 'best'),
#  ('20th Century Fox Video Games', 1981, Decimal('1.35'), 'best'),
#  ('20th Century Fox Video Games', 1982, Decimal('0.59'), 'worst'),
#  ('2D Boy', 2008, Decimal('0.04'), 'both'),
#  ('3DO', 1998, Decimal('0.40'), 'worst'),
#  ('3DO', 1999, Decimal('4.14'), 'best'),
#  ('49Games', 2009, Decimal('0.04'), 'both'),
#  ('505 Games', 2010, Decimal('14.26'), 'best'),
#  ('505 Games', 2003, Decimal('0.10'), 'worst'),
#  ('5pb', 2016, Decimal('0.04'), 'worst'),
#  ('5pb', 2010, Decimal('0.29'), 'best'),
#  ('7G//AMES', 2010, Decimal('0.01'), 'worst'),
#  ('7G//AMES', 2011, Decimal('0.07'), 'best'),
#  ('989 Sports', 1999, Decimal('0.38'), 'both'),
#  ('989 Studios', 1997, Decimal('0.52'), 'worst'),
#  ('989 Studios', 1998, Decimal('7.54'), 'best'),
#  ('Abylight', 2010, Decimal('0.08'), 'both'),
#  ('Acclaim Entertainment', 2004, Decimal('1.06'), 'worst'),
#  ('Acclaim Entertainment', 1998, Decimal('13.71'), 'best'),
#  ('Accolade', 1997, Decimal('1.30'), 'best'),
#  ('Accolade', 1996, Decimal('0.19'), 'worst'),
#  ('Accolade', 1999, Decimal('0.19'), 'worst'),
#  ('Ackkstudios', 2011, Decimal('0.41'), 'best'),
#  ('Ackkstudios', 2009, Decimal('0.07'), 'worst'),
#  ('Acquire', 2006, Decimal('0.05'), 'worst'),
#  ('Acquire', 2011, Decimal('0.30'), 'best'),
#  ('Activision', 2009, Decimal('78.06'), 'best'),
#  ('Activision', 1984, Decimal('0.27'), 'worst'),
#  ('Activision Blizzard', 2014, Decimal('0.48'), 'both'),
#  ('Activision Value', 2009, Decimal('3.29'), 'best'),
#  ('Activision Value', 2005, Decimal('0.05'), 'worst'),
#  ('Adeline Software', 1996, Decimal('0.17'), 'both'),
#  ('Aerosoft', 2013, Decimal('0.02'), 'best'),
#  ('Aerosoft', 2010, Decimal('0.01'), 'worst'),
#  ('Agatsuma Entertainment', 2012, Decimal('0.20'), 'best'),
#  ('Agatsuma Entertainment', 2013, Decimal('0.03'), 'worst'),
#  ('Agetec', 1997, Decimal('0.03'), 'worst'),
#  ('Agetec', 2002, Decimal('1.29'), 'best'),
#  ('Aksys Games', 2014, Decimal('0.18'), 'best'),
#  ('Aksys Games', 2008, Decimal('0.02'), 'worst'),
#  ('Alawar Entertainment', 2009, Decimal('0.04'), 'best'),
#  ('Alawar Entertainment', 2015, Decimal('0.01'), 'worst'),
#  ('Alchemist', 2015, Decimal('0.08'), 'worst'),
#  ('Alchemist', 2006, Decimal('1.24'), 'best'),
#  ('Alchemist', 2009, Decimal('0.08'), 'worst'),
#  ('Alternative Software', 2015, Decimal('0.02'), 'worst'),
#  ('Alternative Software', 2016, Decimal('0.11'), 'best'),
#  ('Altron', 2001, Decimal('0.07'), 'both'),
#  ('Alvion', 2009, Decimal('0.02'), 'both'),
#  ('Alvion', 2010, Decimal('0.02'), 'both'),
#  ('American Softworks', 1996, Decimal('0.23'), 'both'),
#  ('Angel Studios', 1991, Decimal('0.29'), 'best'),
#  ('Angel Studios', 1995, Decimal('0.03'), 'worst'),
#  ('Answer Software', 1982, Decimal('0.50'), 'both'),
#  ('AQ Interactive', 2008, Decimal('0.22'), 'best'),
#  ('AQ Interactive', 2009, Decimal('0.15'), 'worst'),
#  ('Aqua Plus', 2007, Decimal('0.01'), 'worst'),
#  ('Aqua Plus', 2015, Decimal('0.23'), 'best'),
#  ('Aques', 1997, Decimal('0.16'), 'both'),
#  ('Arc System Works', 2012, Decimal('0.03'), 'worst'),
#  ('Arc System Works', 2014, Decimal('0.51'), 'best'),
#  ('Arena Entertainment', 1992, Decimal('4.72'), 'both'),
#  ('Aria', 2006, Decimal('0.07'), 'both'),
#  ('Arika', 2004, Decimal('0.05'), 'best'),
#  ('Arika', 2008, Decimal('0.02'), 'worst'),
#  ('Arika', 2002, Decimal('0.02'), 'worst'),
#  ('ArtDink', 1994, Decimal('0.25'), 'best'),
#  ('ArtDink', 2010, Decimal('0.02'), 'worst'),
#  ('Aruze Corp', 2000, Decimal('0.64'), 'best'),
#  ('Aruze Corp', 1999, Decimal('0.54'), 'worst'),
#  ('ASC Games', 1996, Decimal('1.31'), 'best'),
#  ('ASC Games', 1999, Decimal('0.05'), 'worst'),
#  ('Ascaron Entertainment', 2012, Decimal('0.01'), 'both'),
#  ('Ascaron Entertainment GmbH', 2004, Decimal('0.04'), 'worst'),
#  ('Ascaron Entertainment GmbH', 2008, Decimal('0.07'), 'best'),
#  ('ASCII Entertainment', 2001, Decimal('0.32'), 'worst'),
#  ('ASCII Entertainment', 1997, Decimal('3.32'), 'best'),
#  ('ASCII Media Works', 2014, Decimal('0.01'), 'worst'),
#  ('ASCII Media Works', 2010, Decimal('0.12'), 'best'),
#  ('ASCII Media Works', 2011, Decimal('0.01'), 'worst'),
#  ('Asgard', 2012, Decimal('0.01'), 'worst'),
#  ('Asgard', 2010, Decimal('0.14'), 'best'),
#  ('ASK', 1996, Decimal('0.03'), 'both'),
#  ('Asmik Ace Entertainment', 2006, Decimal('0.04'), 'worst'),
#  ('Asmik Ace Entertainment', 1996, Decimal('0.10'), 'best'),
#  ('Asmik Corp', 1995, Decimal('0.10'), 'best'),
#  ('Asmik Corp', 1994, Decimal('0.07'), 'worst'),
#  ('Aspyr', 2007, Decimal('0.01'), 'worst'),
#  ('Aspyr', 2009, Decimal('0.48'), 'best'),
#  ('Astragon', 2016, Decimal('0.02'), 'worst'),
#  ('Astragon', 2010, Decimal('0.53'), 'best'),
#  ('Asylum Entertainment', 2011, Decimal('0.07'), 'worst'),
#  ('Asylum Entertainment', 2010, Decimal('0.52'), 'best'),
#  ('Atari', 2016, Decimal('0.02'), 'worst'),
#  ('Atari', 2002, Decimal('21.25'), 'best'),
#  ('Athena', 2001, Decimal('0.07'), 'best'),
#  ('Athena', 1999, Decimal('0.02'), 'worst'),
#  ('Atlus', 2012, Decimal('3.01'), 'best'),
#  ('Atlus', 2006, Decimal('0.05'), 'worst'),
#  ('Avalon Interactive', 1982, Decimal('0.17'), 'best'),
#  ('Avalon Interactive', 2003, Decimal('0.04'), 'worst'),
#  ('Avanquest', 2009, Decimal('0.90'), 'best'),
#  ('Avanquest', 2016, Decimal('0.04'), 'worst'),
#  ('Avanquest Software', 2012, Decimal('1.64'), 'best'),
#  ('Avanquest Software', 2013, Decimal('0.01'), 'worst'),
#  ('Axela', 1998, Decimal('0.25'), 'both'),
#  ('BAM! Entertainment', 2002, Decimal('2.88'), 'best'),
#  ('BAM! Entertainment', 2004, Decimal('0.10'), 'worst'),
#  ('Banpresto', 1993, Decimal('1.70'), 'best'),
#  ('Banpresto', 1992, Decimal('0.16'), 'worst'),
#  ('Benesse', 2008, Decimal('0.14'), 'worst'),
#  ('Benesse', 2007, Decimal('0.19'), 'best'),
#  ('Berkeley', 2001, Decimal('0.03'), 'both'),
#  ('Bethesda Softworks', 2006, Decimal('0.10'), 'worst'),
#  ('Bethesda Softworks', 2011, Decimal('25.09'), 'best'),
#  ('Big Ben Interactive', 2011, Decimal('0.01'), 'worst'),
#  ('Big Ben Interactive', 2009, Decimal('0.81'), 'best'),
#  ('Big Fish Games', 2014, Decimal('0.03'), 'best'),
#  ('Big Fish Games', 2008, Decimal('0.02'), 'worst'),
#  ('Bigben Interactive', 2015, Decimal('0.84'), 'both'),
#  ('bitComposer Games', 2009, Decimal('0.03'), 'worst'),
#  ('bitComposer Games', 2011, Decimal('0.38'), 'best'),
#  ('Black Bean Games', 2010, Decimal('1.20'), 'best'),
#  ('Black Bean Games', 2005, Decimal('0.01'), 'worst'),
#  ('Black Label Games', 2002, Decimal('1.20'), 'both'),
#  ('Blast! Entertainment Ltd', 2008, Decimal('0.02'), 'worst'),
#  ('Blast! Entertainment Ltd', 2009, Decimal('0.19'), 'best'),
#  ('Blue Byte', 2001, Decimal('0.03'), 'both'),
#  ('BMG Interactive Entertainment', 1996, Decimal('0.27'), 'worst'),
#  ('BMG Interactive Entertainment', 1998, Decimal('0.58'), 'best'),
#  ('Bohemia Interactive', 2013, Decimal('0.12'), 'both'),
#  ('Bomb', 1982, Decimal('0.22'), 'both'),
#  ('Boost On', 2013, Decimal('0.01'), 'both'),
#  ('BPS', 1991, Decimal('0.32'), 'best'),
#  ('BPS', 1994, Decimal('0.20'), 'worst'),
#  ('Brash Entertainment', 2008, Decimal('1.02'), 'best'),
#  ('Brash Entertainment', 2007, Decimal('0.21'), 'worst'),
#  ('Broccoli', 2013, Decimal('0.26'), 'best'),
#  ('Broccoli', 2010, Decimal('0.02'), 'worst'),
#  ('BushiRoad', 2012, Decimal('0.03'), 'both'),
#  ('Capcom', 1994, Decimal('0.16'), 'worst'),
#  ('Capcom', 2009, Decimal('19.47'), 'best'),
#  ('Cave', 2011, Decimal('0.10'), 'best'),
#  ('Cave', 2008, Decimal('0.10'), 'best'),
#  ('Cave', 2013, Decimal('0.01'), 'worst'),
#  ('CBS Electronics', 1982, Decimal('0.31'), 'both'),
#  ('CCP', 2003, Decimal('0.22'), 'both'),
#  ('CDV Software Entertainment', 2008, Decimal('0.11'), 'best'),
#  ('CDV Software Entertainment', 2005, Decimal('0.01'), 'worst'),
#  ('ChunSoft', 2006, Decimal('0.03'), 'worst'),
#  ('ChunSoft', 1994, Decimal('0.81'), 'best'),
#  ('City Interactive', 2010, Decimal('1.87'), 'best'),
#  ('City Interactive', 2014, Decimal('0.07'), 'worst'),
#  ('Cloud Imperium Games Corporation', 2012, Decimal('0.08'), 'both'),
#  ('Coconuts Japan', 1996, Decimal('0.02'), 'worst'),
#  ('Coconuts Japan', 1993, Decimal('0.05'), 'best'),
#  ('Codemasters', 2009, Decimal('8.43'), 'best'),
#  ('Codemasters', 2006, Decimal('0.23'), 'worst'),
#  ('Codemasters Online', 2008, Decimal('0.02'), 'both'),
#  ('CokeM Interactive', 2007, Decimal('0.31'), 'both'),
#  ('Coleco', 1981, Decimal('2.79'), 'best'),
#  ('Coleco', 1982, Decimal('0.27'), 'worst'),
#  ('Comfort', 2013, Decimal('0.02'), 'worst'),
#  ('Comfort', 2011, Decimal('0.08'), 'best'),
#  ('Comfort', 2012, Decimal('0.02'), 'worst'),
#  ('Commseed', 2008, Decimal('0.01'), 'both'),
#  ('Compile', 1996, Decimal('0.02'), 'worst'),
#  ('Compile', 1997, Decimal('1.94'), 'best'),
#  ('Compile Heart', 2010, Decimal('0.26'), 'best'),
#  ('Compile Heart', 2009, Decimal('0.01'), 'worst'),
#  ('Conspiracy Entertainment', 2001, Decimal('0.29'), 'best'),
#  ('Conspiracy Entertainment', 2002, Decimal('0.03'), 'worst'),
#  ('Core Design Ltd.', 1994, Decimal('0.19'), 'best'),
#  ('Core Design Ltd.', 1995, Decimal('0.10'), 'worst'),
#  ('CPG Products', 1982, Decimal('0.54'), 'both'),
#  ('Crave Entertainment', 2000, Decimal('2.44'), 'best'),
#  ('Crave Entertainment', 2003, Decimal('0.07'), 'worst'),
#  ('Creative Core', 2009, Decimal('0.03'), 'worst'),
#  ('Creative Core', 2008, Decimal('0.07'), 'best'),
#  ('Crimson Cow', 2008, Decimal('0.02'), 'worst'),
#  ('Crimson Cow', 2011, Decimal('0.06'), 'best'),
#  ('Crystal Dynamics', 1996, Decimal('0.59'), 'worst'),
#  ('Crystal Dynamics', 1995, Decimal('1.12'), 'best'),
#  ('CTO SpA', 1997, Decimal('0.02'), 'worst'),
#  ('CTO SpA', 1996, Decimal('0.88'), 'best'),
#  ('Culture Brain', 2010, Decimal('0.02'), 'worst'),
#  ('Culture Brain', 1991, Decimal('0.20'), 'best'),
#  ('Culture Brain', 2008, Decimal('0.02'), 'worst'),
#  ('Culture Publishers', 1998, Decimal('0.09'), 'both'),
#  ('CyberFront', 2007, Decimal('0.02'), 'worst'),
#  ('CyberFront', 2010, Decimal('0.11'), 'best'),
#  ('CyberFront', 2009, Decimal('0.02'), 'worst'),
#  ('CyberFront', 2011, Decimal('0.02'), 'worst'),
#  ('Cygames', 2015, Decimal('0.03'), 'both'),
#  ('D3Publisher', 2000, Decimal('0.07'), 'worst'),
#  ('D3Publisher', 2007, Decimal('6.31'), 'best'),
#  ('Daedalic', 2012, Decimal('0.15'), 'best'),
#  ('Daedalic', 2010, Decimal('0.02'), 'worst'),
#  ('Daedalic Entertainment', 2012, Decimal('0.03'), 'worst'),
#  ('Daedalic Entertainment', 2013, Decimal('0.11'), 'best'),
#  ('Daito', 2006, Decimal('0.23'), 'both'),
#  ('Data Age', 1982, Decimal('0.32'), 'worst'),
#  ('Data Age', 1981, Decimal('0.39'), 'best'),
#  ('Data Design Interactive', 2008, Decimal('0.13'), 'best'),
#  ('Data Design Interactive', 2009, Decimal('0.07'), 'worst'),
#  ('Data East', 1998, Decimal('0.11'), 'best'),
#  ('Data East', 1995, Decimal('0.04'), 'worst'),
#  ('Datam Polystar', 2002, Decimal('0.02'), 'best'),
#  ('Datam Polystar', 2007, Decimal('0.01'), 'worst'),
#  ('Deep Silver', 2007, Decimal('0.02'), 'worst'),
#  ('Deep Silver', 2011, Decimal('6.64'), 'best'),
#  ('Destination Software, Inc', 2002, Decimal('0.02'), 'worst'),
#  ('Destination Software, Inc', 2007, Decimal('0.37'), 'best'),
#  ('Destineer', 2009, Decimal('1.89'), 'best'),
#  ('Destineer', 2011, Decimal('0.08'), 'worst'),
#  ('Detn8 Games', 2007, Decimal('0.23'), 'both'),
#  ('Devolver Digital', 2010, Decimal('0.02'), 'both'),
#  ('Devolver Digital', 2015, Decimal('0.02'), 'both'),
#  ('DHM Interactive', 2007, Decimal('0.14'), 'best'),
#  ('DHM Interactive', 2009, Decimal('0.04'), 'worst'),
#  ('DigiCube', 2002, Decimal('0.06'), 'both'),
#  ('Disney Interactive Studios', 2008, Decimal('22.09'), 'best'),
#  ('Disney Interactive Studios', 2002, Decimal('0.25'), 'worst'),
#  ('Dorart', 2008, Decimal('0.02'), 'best'),
#  ('Dorart', 2010, Decimal('0.01'), 'worst'),
#  ('dramatic create', 2015, Decimal('0.08'), 'best'),
#  ('dramatic create', 2016, Decimal('0.03'), 'worst'),
#  ('DreamCatcher Interactive', 2005, Decimal('0.02'), 'worst'),
#  ('DreamCatcher Interactive', 2004, Decimal('0.02'), 'worst'),
#  ('DreamCatcher Interactive', 2009, Decimal('0.47'), 'best'),
#  ('DreamWorks Interactive', 1998, Decimal('0.13'), 'both'),
#  ('DSI Games', 2005, Decimal('0.17'), 'best'),
#  ('DSI Games', 2006, Decimal('0.04'), 'worst'),
#  ('DTP Entertainment', 2007, Decimal('0.02'), 'worst'),
#  ('DTP Entertainment', 2009, Decimal('1.01'), 'best'),
#  ('Dusenberry Martin Racing', 2016, Decimal('0.05'), 'both'),
#  ('EA Games', 2012, Decimal('0.15'), 'both'),
#  ('Easy Interactive', 2012, Decimal('0.05'), 'both'),
#  ('Ecole', 2009, Decimal('0.06'), 'both'),
#  ('Edia', 2006, Decimal('0.07'), 'best'),
#  ('Edia', 2009, Decimal('0.02'), 'worst'),
#  ('Eidos Interactive', 2001, Decimal('2.21'), 'worst'),
#  ('Eidos Interactive', 1997, Decimal('13.55'), 'best'),
#  ('Electronic Arts', 1992, Decimal('0.06'), 'worst'),
#  ('Electronic Arts', 2009, Decimal('86.20'), 'best'),
#  ('Electronic Arts Victor', 1996, Decimal('0.42'), 'both'),
#  ('Elf', 1996, Decimal('0.36'), 'best'),
#  ('Elf', 1997, Decimal('0.28'), 'worst'),
#  ('Elite', 1996, Decimal('0.07'), 'both'),
#  ('Empire Interactive', 1999, Decimal('0.02'), 'worst'),
#  ('Empire Interactive', 2003, Decimal('2.41'), 'best'),
#  ('Encore', 2003, Decimal('0.02'), 'worst'),
#  ('Encore', 2001, Decimal('0.03'), 'best'),
#  ('Encore', 2005, Decimal('0.02'), 'worst'),
#  ('Enix Corporation', 2000, Decimal('5.36'), 'best'),
#  ('Enix Corporation', 2003, Decimal('0.66'), 'worst'),
#  ('Enjoy Gaming ltd.', 2009, Decimal('0.10'), 'both'),
#  ('Enterbrain', 2004, Decimal('0.61'), 'best'),
#  ('Enterbrain', 2007, Decimal('0.01'), 'worst'),
#  ('EON Digital Entertainment', 1999, Decimal('0.01'), 'both'),
#  ('Epic Games', 2016, Decimal('0.01'), 'both'),
#  ('Epoch', 1993, Decimal('0.05'), 'worst'),
#  ('Epoch', 1995, Decimal('0.51'), 'best'),
#  ('Ertain', 2007, Decimal('0.05'), 'both'),
#  ('ESP', 1997, Decimal('0.42'), 'best'),
#  ('ESP', 2002, Decimal('0.03'), 'worst'),
#  ('Essential Games', 2006, Decimal('0.06'), 'worst'),
#  ('Essential Games', 2005, Decimal('0.17'), 'best'),
#  ('Evolution Games', 1998, Decimal('0.07'), 'both'),
#  ('Evolved Games', 2004, Decimal('0.09'), 'worst'),
#  ('Evolved Games', 2011, Decimal('0.13'), 'best'),
#  ('Excalibur Publishing', 2011, Decimal('0.14'), 'both'),
#  ('Excalibur Publishing', 2012, Decimal('0.14'), 'both'),
#  ('Experience Inc.', 2015, Decimal('0.04'), 'best'),
#  ('Experience Inc.', 2016, Decimal('0.01'), 'worst'),
#  ('Experience Inc.', 2014, Decimal('0.01'), 'worst'),
#  ('Extreme Entertainment Group', 2015, Decimal('0.03'), 'both'),
#  ('Falcom Corporation', 2013, Decimal('0.03'), 'worst'),
#  ('Falcom Corporation', 2010, Decimal('0.36'), 'best'),
#  ('Fields', 2012, Decimal('0.03'), 'both'),
#  ('Flashpoint Games', 2005, Decimal('0.04'), 'both'),
#  ('Flashpoint Games', 2010, Decimal('0.04'), 'both'),
#  ('Flight-Plan', 2007, Decimal('0.08'), 'best'),
#  ('Flight-Plan', 2009, Decimal('0.04'), 'worst'),
#  ('Focus Home Interactive', 2006, Decimal('0.03'), 'worst'),
#  ('Focus Home Interactive', 2014, Decimal('2.05'), 'best'),
#  ('Focus Home Interactive', 2007, Decimal('0.03'), 'worst'),
#  ('Focus Multimedia', 2015, Decimal('0.02'), 'worst'),
#  ('Focus Multimedia', 2012, Decimal('0.03'), 'best'),
#  ('fonfun', 2008, Decimal('0.02'), 'both'),
#  ('Foreign Media Games', 2010, Decimal('0.63'), 'both'),
#  ('Fortyfive', 1998, Decimal('0.06'), 'both'),
#  ('Fox Interactive', 2000, Decimal('0.16'), 'worst'),
#  ('Fox Interactive', 1997, Decimal('4.00'), 'best'),
#  ('From Software', 2010, Decimal('0.03'), 'worst'),
#  ('From Software', 1997, Decimal('0.28'), 'best'),
#  ('Fuji', 1995, Decimal('0.03'), 'both'),
#  ('Funbox Media', 2011, Decimal('0.86'), 'best'),
#  ('Funbox Media', 2015, Decimal('0.01'), 'worst'),
#  ('Funcom', 2010, Decimal('0.03'), 'worst'),
#  ('Funcom', 2012, Decimal('0.17'), 'best'),
#  ('FunSoft', 1996, Decimal('0.12'), 'both'),
#  ('Funsta', 2006, Decimal('0.02'), 'worst'),
#  ('Funsta', 2007, Decimal('0.14'), 'best'),
#  ('FuRyu', 2010, Decimal('0.01'), 'worst'),
#  ('FuRyu', 2015, Decimal('0.52'), 'best'),
#  ('FuRyu Corporation', 2015, Decimal('0.03'), 'both'),
#  ('G.Rev', 2009, Decimal('0.01'), 'worst'),
#  ('G.Rev', 2010, Decimal('0.03'), 'best'),
#  ('Gaga', 1996, Decimal('0.02'), 'both'),
#  ('Gainax Network Systems', 1998, Decimal('0.16'), 'both'),
#  ('Gakken', 2007, Decimal('0.04'), 'both'),
#  ('Game Arts', 1994, Decimal('0.14'), 'both'),
#  ('Game Factory', 2007, Decimal('1.53'), 'best'),
#  ('Game Factory', 2003, Decimal('0.04'), 'worst'),
#  ('Game Factory', 2008, Decimal('1.53'), 'best'),
#  ('Game Life', 2009, Decimal('0.17'), 'best'),
#  ('Game Life', 2007, Decimal('0.13'), 'worst'),
#  ('Gamebridge', 2008, Decimal('0.52'), 'best'),
#  ('Gamebridge', 2009, Decimal('0.21'), 'worst'),
#  ('Gamecock', 2008, Decimal('0.20'), 'both'),
#  ('Gameloft', 2007, Decimal('0.11'), 'both'),
#  ('GameMill Entertainment', 2011, Decimal('0.99'), 'best'),
#  ('GameMill Entertainment', 2010, Decimal('0.18'), 'worst'),
#  ('GameTek', 1998, Decimal('0.10'), 'both'),
#  ('Gathering of Developers', 2001, Decimal('0.67'), 'best'),
#  ('Gathering of Developers', 2003, Decimal('0.06'), 'worst'),
#  ('General Entertainment', 1998, Decimal('0.14'), 'both'),
#  ('Genki', 2012, Decimal('0.05'), 'worst'),
#  ('Genki', 2003, Decimal('1.09'), 'best'),
#  ('Genterprise', 2009, Decimal('0.01'), 'both'),
#  ('Ghostlight', 2011, Decimal('0.70'), 'best'),
#  ('Ghostlight', 2008, Decimal('0.11'), 'worst'),
#  ('Giga', 2014, Decimal('0.02'), 'both'),
#  ('Giza10', 2012, Decimal('0.02'), 'both'),
#  ('Glams', 1995, Decimal('0.08'), 'both'),
#  ('Global A Entertainment', 2006, Decimal('0.03'), 'worst'),
#  ('Global A Entertainment', 2007, Decimal('0.07'), 'best'),
#  ('Global Star', 2004, Decimal('5.53'), 'best'),
#  ('Global Star', 2006, Decimal('0.09'), 'worst'),
#  ('GN Software', 2006, Decimal('0.01'), 'worst'),
#  ('GN Software', 2010, Decimal('0.01'), 'worst'),
#  ('GN Software', 2008, Decimal('0.03'), 'best'),
#  ('GOA', 2008, Decimal('0.02'), 'both'),
#  ('Gotham Games', 2004, Decimal('0.61'), 'worst'),
#  ('Gotham Games', 2002, Decimal('1.57'), 'best'),
#  ('Graffiti', 2008, Decimal('0.04'), 'worst'),
#  ('Graffiti', 2010, Decimal('0.20'), 'best'),
#  ('Grand Prix Games', 2007, Decimal('0.06'), 'both'),
#  ('Graphsim Entertainment', 2005, Decimal('0.02'), 'both'),
#  ('Gremlin Interactive Ltd', 1997, Decimal('0.32'), 'worst'),
#  ('Gremlin Interactive Ltd', 1996, Decimal('0.39'), 'best'),
#  ('Gremlin Interactive Ltd', 1998, Decimal('0.39'), 'best'),
#  ('Griffin International', 2010, Decimal('0.09'), 'both'),
#  ('Groove Games', 2005, Decimal('0.06'), 'best'),
#  ('Groove Games', 2006, Decimal('0.03'), 'worst'),
#  ('GSP', 2009, Decimal('1.60'), 'best'),
#  ('GSP', 2011, Decimal('0.32'), 'worst'),
#  ('GT Interactive', 1995, Decimal('0.27'), 'worst'),
#  ('GT Interactive', 1999, Decimal('7.06'), 'best'),
#  ('GungHo', 2014, Decimal('0.04'), 'worst'),
#  ('GungHo', 2013, Decimal('1.66'), 'best'),
#  ('Gust', 1997, Decimal('0.25'), 'best'),
#  ('Gust', 1996, Decimal('0.01'), 'worst'),
#  ('Hackberry', 2010, Decimal('0.01'), 'worst'),
#  ('Hackberry', 2007, Decimal('0.22'), 'best'),
#  ('HAL Laboratory', 1989, Decimal('0.06'), 'both'),
#  ('Hamster Corporation', 2006, Decimal('0.02'), 'worst'),
#  ('Hamster Corporation', 2002, Decimal('0.28'), 'best'),
#  ('Happinet', 2014, Decimal('0.11'), 'best'),
#  ('Happinet', 2015, Decimal('0.03'), 'worst'),
#  ('Harmonix Music Systems', 2015, Decimal('0.80'), 'both'),
#  ('Hasbro Interactive', 1997, Decimal('6.38'), 'best'),
#  ('Hasbro Interactive', 2006, Decimal('0.02'), 'worst'),
#  ('Havas Interactive', 2000, Decimal('0.13'), 'both'),
#  ('Headup Games', 2013, Decimal('0.03'), 'both'),
#  ('Hearty Robin', 1996, Decimal('0.09'), 'both'),
#  ('Hect', 1995, Decimal('0.04'), 'worst'),
#  ('Hect', 1994, Decimal('0.27'), 'best'),
#  ('Hello Games', 2016, Decimal('1.60'), 'both'),
#  ('Her Interactive', 2011, Decimal('0.03'), 'both'),
#  ('Hip Interactive', 2004, Decimal('0.19'), 'best'),
#  ('Hip Interactive', 2005, Decimal('0.17'), 'worst'),
#  ('HMH Interactive', 2009, Decimal('0.11'), 'best'),
#  ('HMH Interactive', 2008, Decimal('0.03'), 'worst'),
#  ('Home Entertainment Suppliers', 2011, Decimal('0.39'), 'best'),
#  ('Home Entertainment Suppliers', 2010, Decimal('0.06'), 'worst'),
#  ('Hudson Entertainment', 1997, Decimal('0.79'), 'best'),
#  ('Hudson Entertainment', 2008, Decimal('0.01'), 'worst'),
#  ('Hudson Soft', 1998, Decimal('0.03'), 'worst'),
#  ('Hudson Soft', 1986, Decimal('4.66'), 'best'),
#  ('Human Entertainment', 1996, Decimal('0.12'), 'worst'),
#  ('Human Entertainment', 1994, Decimal('0.73'), 'best'),
#  ('HuneX', 2015, Decimal('0.03'), 'both'),
#  ('Iceberg Interactive', 2012, Decimal('0.02'), 'worst'),
#  ('Iceberg Interactive', 2011, Decimal('0.06'), 'best'),
#  ('id Software', 1992, Decimal('0.03'), 'both'),
#  ('Idea Factory', 2017, Decimal('0.01'), 'worst'),
#  ('Idea Factory', 2010, Decimal('0.68'), 'best'),
#  ('Idea Factory International', 2015, Decimal('0.23'), 'worst'),
#  ('Idea Factory International', 2014, Decimal('0.38'), 'best'),
#  ('IE Institute', 2012, Decimal('0.02'), 'worst'),
#  ('IE Institute', 2006, Decimal('0.73'), 'best'),
#  ('Ignition Entertainment', 2003, Decimal('0.23'), 'worst'),
#  ('Ignition Entertainment', 2008, Decimal('1.48'), 'best'),
#  ('Illusion Softworks', 2004, Decimal('0.70'), 'both'),
#  ('Imadio', 1997, Decimal('0.14'), 'both'),
#  ('Image Epoch', 2012, Decimal('0.10'), 'both'),
#  ('imageepoch Inc.', 2014, Decimal('0.04'), 'both'),
#  ('Imageworks', 1995, Decimal('0.02'), 'both'),
#  ('Imagic', 1981, Decimal('4.82'), 'both'),
#  ('Imagineer', 1999, Decimal('0.63'), 'best'),
#  ('Imagineer', 2001, Decimal('0.12'), 'worst'),
#  ('Imax', 1993, Decimal('0.06'), 'both'),
#  ('Indie Games', 2004, Decimal('0.32'), 'both'),
#  ('Infogrames', 2003, Decimal('0.14'), 'worst'),
#  ('Infogrames', 2002, Decimal('8.46'), 'best'),
#  ('Insomniac Games', 2016, Decimal('0.12'), 'both'),
#  ('Interchannel', 2006, Decimal('0.08'), 'best'),
#  ('Interchannel', 2008, Decimal('0.02'), 'worst'),
#  ('Interchannel-Holon', 2007, Decimal('0.01'), 'both'),
#  ('Intergrow', 2015, Decimal('0.03'), 'both'),
#  ('Interplay', 1996, Decimal('1.02'), 'best'),
#  ('Interplay', 1993, Decimal('0.01'), 'worst'),
#  ('Interplay Productions', 1997, Decimal('0.10'), 'both'),
#  ('Interworks Unlimited, Inc.', 2012, Decimal('0.01'), 'both'),
#  ('Inti Creates', 2016, Decimal('0.01'), 'both'),
#  ('Introversion Software', 2016, Decimal('0.02'), 'both'),
#  ('inXile Entertainment', 2015, Decimal('0.10'), 'both'),
#  ('Irem Software Engineering', 2008, Decimal('0.15'), 'best'),
#  ('Irem Software Engineering', 2012, Decimal('0.02'), 'worst'),
#  ('ITT Family Games', 1982, Decimal('0.34'), 'both'),
#  ('Ivolgamus', 2008, Decimal('0.04'), 'both'),
#  ('iWin', 2011, Decimal('0.06'), 'both'),
#  ('Jack of All Games', 2011, Decimal('0.04'), 'worst'),
#  ('Jack of All Games', 2005, Decimal('0.38'), 'best'),
#  ('Jaleco', 1995, Decimal('0.60'), 'best'),
#  ('Jaleco', 1999, Decimal('0.02'), 'worst'),
#  ('Jester Interactive', 2002, Decimal('0.71'), 'best'),
#  ('Jester Interactive', 2003, Decimal('0.04'), 'worst'),
#  ('Jorudan', 2002, Decimal('0.36'), 'best'),
#  ('Jorudan', 2003, Decimal('0.29'), 'worst'),
#  ('JoWood Productions', 2002, Decimal('0.02'), 'worst'),
#  ('JoWood Productions', 2008, Decimal('0.43'), 'best'),
#  ('Just Flight', 2010, Decimal('0.03'), 'both'),
#  ('JVC', 1999, Decimal('0.02'), 'worst'),
#  ('JVC', 1996, Decimal('2.49'), 'best'),
#  ('Kadokawa Games', 2016, Decimal('0.22'), 'best'),
#  ('Kadokawa Games', 2012, Decimal('0.02'), 'worst'),
#  ('Kadokawa Shoten', 2006, Decimal('0.02'), 'worst'),
#  ('Kadokawa Shoten', 2004, Decimal('0.02'), 'worst'),
#  ('Kadokawa Shoten', 1998, Decimal('0.83'), 'best'),
#  ('Kaga Create', 2013, Decimal('0.01'), 'worst'),
#  ('Kaga Create', 2015, Decimal('0.13'), 'best'),
#  ('Kalypso Media', 2007, Decimal('0.01'), 'worst'),
#  ('Kalypso Media', 2011, Decimal('0.63'), 'best'),
#  ('Kamui', 2010, Decimal('0.03'), 'both'),
#  ('Kando Games', 2006, Decimal('0.03'), 'both'),
#  ('Karin Entertainment', 2010, Decimal('0.02'), 'both'),
#  ('Kemco', 2005, Decimal('0.02'), 'worst'),
#  ('Kemco', 2003, Decimal('0.69'), 'best'),
#  ('KID', 2006, Decimal('0.05'), 'best'),
#  ('KID', 1998, Decimal('0.03'), 'worst'),
#  ('Kids Station', 2007, Decimal('0.03'), 'both'),
#  ('King Records', 2002, Decimal('0.02'), 'both'),
#  ('Knowledge Adventure', 2003, Decimal('0.61'), 'worst'),
#  ('Knowledge Adventure', 2009, Decimal('0.86'), 'best'),
#  ('Koch Media', 2008, Decimal('3.01'), 'best'),
#  ('Koch Media', 2016, Decimal('0.04'), 'worst'),
#  ('Kokopeli Digital Studios', 1995, Decimal('0.03'), 'both'),
#  ('Konami Digital Entertainment', 2008, Decimal('27.82'), 'best'),
#  ('Konami Digital Entertainment', 1992, Decimal('0.26'), 'worst'),
#  ('Kool Kizz', 2003, Decimal('0.04'), 'both'),
#  ('KSS', 1996, Decimal('0.03'), 'both'),
#  ('Laguna', 1995, Decimal('0.63'), 'best'),
#  ('Laguna', 1994, Decimal('0.36'), 'worst'),
#  ('Legacy Interactive', 2008, Decimal('0.04'), 'both'),
#  ('LEGO Media', 2002, Decimal('0.14'), 'worst'),
#  ('LEGO Media', 1999, Decimal('1.18'), 'best'),
#  ('Level 5', 2014, Decimal('2.68'), 'best'),
#  ('Level 5', 2009, Decimal('0.35'), 'worst'),
#  ('Lexicon Entertainment', 2007, Decimal('0.03'), 'best'),
#  ('Lexicon Entertainment', 2008, Decimal('0.02'), 'worst'),
#  ('Licensed 4U', 2012, Decimal('0.07'), 'both'),
#  ('Lighthouse Interactive', 2007, Decimal('0.02'), 'both'),
#  ('Liquid Games', 2002, Decimal('0.26'), 'best'),
#  ('Liquid Games', 2006, Decimal('0.01'), 'worst'),
#  ('Little Orbit', 2013, Decimal('0.05'), 'worst'),
#  ('Little Orbit', 2014, Decimal('1.14'), 'best'),
#  ('Locus', 1998, Decimal('0.07'), 'both'),
#  ('LSP Games', 2003, Decimal('0.09'), 'best'),
#  ('LSP Games', 2002, Decimal('0.03'), 'worst'),
#  ('LucasArts', 2007, Decimal('18.70'), 'best'),
#  ('LucasArts', 2000, Decimal('0.26'), 'worst'),
#  ('Mad Catz', 2006, Decimal('0.03'), 'worst'),
#  ('Mad Catz', 2004, Decimal('0.20'), 'best'),
#  ('Magical Company', 1998, Decimal('0.41'), 'both'),
#  ('Magix', 2009, Decimal('0.04'), 'worst'),
#  ('Magix', 2001, Decimal('0.31'), 'best'),
#  ('Majesco Entertainment', 2002, Decimal('0.05'), 'worst'),
#  ('Majesco Entertainment', 2009, Decimal('3.43'), 'best'),
#  ('Mamba Games', 2010, Decimal('0.02'), 'worst'),
#  ('Mamba Games', 2008, Decimal('0.03'), 'best'),
#  ('Marvel Entertainment', 2015, Decimal('0.05'), 'both'),
#  ('Marvelous Entertainment', 2012, Decimal('1.05'), 'best'),
#  ('Marvelous Entertainment', 2016, Decimal('0.01'), 'worst'),
#  ('Marvelous Games', 2015, Decimal('0.02'), 'both'),
#  ('Marvelous Interactive', 2003, Decimal('0.03'), 'worst'),
#  ('Marvelous Interactive', 2011, Decimal('1.00'), 'best'),
#  ('Masque Publishing', 2011, Decimal('0.02'), 'both'),
#  ('Mastertronic', 2012, Decimal('0.01'), 'worst'),
#  ('Mastertronic', 2011, Decimal('1.58'), 'best'),
#  ('Mastiff', 2005, Decimal('0.08'), 'worst'),
#  ('Mastiff', 2010, Decimal('1.17'), 'best'),
#  ('Mattel Interactive', 2000, Decimal('0.23'), 'worst'),
#  ('Mattel Interactive', 1981, Decimal('2.53'), 'best'),
#  ('Max Five', 2001, Decimal('0.05'), 'both'),
#  ('Maximum Family Games', 2012, Decimal('0.03'), 'both'),
#  ('Maxis', 1988, Decimal('0.03'), 'worst'),
#  ('Maxis', 1992, Decimal('2.14'), 'best'),
#  ('MC2 Entertainment', 2004, Decimal('0.06'), 'best'),
#  ('MC2 Entertainment', 2005, Decimal('0.02'), 'worst'),
#  ('Media Entertainment', 2002, Decimal('0.01'), 'both'),
#  ('Media Factory', 2001, Decimal('0.15'), 'best'),
#  ('Media Factory', 2000, Decimal('0.14'), 'worst'),
#  ('Media Rings', 1994, Decimal('0.36'), 'best'),
#  ('Media Rings', 1995, Decimal('0.10'), 'worst'),
#  ('Media Works', 1998, Decimal('0.09'), 'best'),
#  ('Media Works', 2007, Decimal('0.02'), 'worst'),
#  ('MediaQuest', 1995, Decimal('0.05'), 'both'),
#  ('Men-A-Vision', 1981, Decimal('0.77'), 'both'),
#  ('Mentor Interactive', 2011, Decimal('0.01'), 'worst'),
#  ('Mentor Interactive', 2009, Decimal('0.99'), 'best'),
#  ('Mercury Games', 2008, Decimal('0.13'), 'best'),
#  ('Mercury Games', 2007, Decimal('0.08'), 'worst'),
#  ('Merscom LLC', 2009, Decimal('0.20'), 'both'),
#  ('Metro 3D', 2008, Decimal('0.05'), 'worst'),
#  ('Metro 3D', 2002, Decimal('0.75'), 'best'),
#  ('Michaelsoft', 2006, Decimal('0.01'), 'both'),
#  ('Micro Cabin', 1994, Decimal('0.02'), 'worst'),
#  ('Micro Cabin', 1996, Decimal('0.10'), 'best'),
#  ('Microids', 2003, Decimal('0.12'), 'best'),
#  ('Microids', 2016, Decimal('0.04'), 'worst'),
#  ('Microprose', 1999, Decimal('1.06'), 'best'),
#  ('Microprose', 1997, Decimal('0.01'), 'worst'),
#  ('Microsoft Game Studios', 2010, Decimal('49.16'), 'best'),
#  ('Microsoft Game Studios', 1999, Decimal('0.10'), 'worst'),
#  ('Midas Interactive Entertainment', 1997, Decimal('0.02'), 'worst'),
#  ('Midas Interactive Entertainment', 2000, Decimal('1.09'), 'best'),
#  ('Midway Games', 2008, Decimal('9.28'), 'best'),
#  ('Midway Games', 1996, Decimal('0.13'), 'worst'),
#  ('Milestone', 2008, Decimal('0.08'), 'both'),
#  ('Milestone S.r.l', 2016, Decimal('0.05'), 'both'),
#  ('Milestone S.r.l.', 2016, Decimal('0.14'), 'worst'),
#  ('Milestone S.r.l.', 2015, Decimal('0.73'), 'best'),
#  ('Minato Station', 2008, Decimal('0.02'), 'best'),
#  ('Minato Station', 2012, Decimal('0.02'), 'best'),
#  ('Minato Station', 2015, Decimal('0.01'), 'worst'),
#  ('Mindscape', 2009, Decimal('3.49'), 'best'),
#  ('Mindscape', 2000, Decimal('0.02'), 'worst'),
#  ('Mirai Shounen', 2008, Decimal('0.02'), 'both'),
#  ('Misawa', 1994, Decimal('0.02'), 'worst'),
#  ('Misawa', 1993, Decimal('0.05'), 'best'),
#  ('Mitsui', 1998, Decimal('0.08'), 'both'),
#  ('mixi, Inc', 2015, Decimal('0.86'), 'both'),
#  ('MLB.com', 2016, Decimal('0.04'), 'both'),
#  ('Mojang', 2015, Decimal('2.89'), 'both'),
#  ('Monte Christo Multimedia', 2007, Decimal('0.05'), 'both'),
#  ('Moss', 2008, Decimal('0.12'), 'best'),
#  ('Moss', 2013, Decimal('0.01'), 'worst'),
#  ('MTO', 2006, Decimal('0.16'), 'best'),
#  ('MTO', 2008, Decimal('0.01'), 'worst'),
#  ('MTV Games', 2009, Decimal('6.95'), 'best'),
#  ('MTV Games', 2011, Decimal('0.21'), 'worst'),
#  ('Mud Duck Productions', 2003, Decimal('0.30'), 'worst'),
#  ('Mud Duck Productions', 2004, Decimal('0.55'), 'best'),
#  ('Mumbo Jumbo', 2007, Decimal('0.35'), 'best'),
#  ('Mumbo Jumbo', 2006, Decimal('0.02'), 'worst'),
#  ('Mycom', 1985, Decimal('0.02'), 'both'),
#  ('Myelin Media', 2006, Decimal('0.13'), 'both'),
#  ('Mystique', 1981, Decimal('0.82'), 'both'),
#  ('Namco Bandai Games', 1990, Decimal('0.63'), 'worst'),
#  ('Namco Bandai Games', 2011, Decimal('22.08'), 'best'),
#  ('Natsume', 1996, Decimal('1.25'), 'best'),
#  ('Natsume', 2009, Decimal('0.08'), 'worst'),
#  ('Navarre Corp', 2008, Decimal('0.05'), 'both'),
#  ('Naxat Soft', 2008, Decimal('0.01'), 'both'),
#  ('NCS', 1998, Decimal('0.09'), 'worst'),
#  ('NCS', 1996, Decimal('0.20'), 'best'),
#  ('NCSoft', 2006, Decimal('0.05'), 'worst'),
#  ('NCSoft', 2012, Decimal('2.30'), 'best'),
#  ('NDA Productions', 2002, Decimal('0.12'), 'both'),
#  ('NEC', 1995, Decimal('0.14'), 'worst'),
#  ('NEC', 1996, Decimal('0.29'), 'best'),
#  ('NEC Interchannel', 1998, Decimal('0.33'), 'best'),
#  ('NEC Interchannel', 2008, Decimal('0.04'), 'worst'),
#  ('Neko Entertainment', 2009, Decimal('0.02'), 'worst'),
#  ('Neko Entertainment', 2010, Decimal('0.18'), 'best'),
#  ('NetRevo', 2010, Decimal('0.02'), 'best'),
#  ('NetRevo', 2012, Decimal('0.01'), 'worst'),
#  ('New', 1995, Decimal('0.36'), 'both'),
#  ('New World Computing', 1992, Decimal('0.01'), 'both'),
#  ('NewKidCo', 1998, Decimal('0.55'), 'best'),
#  ('NewKidCo', 2001, Decimal('0.01'), 'worst'),
#  ('Nexon', 2010, Decimal('0.03'), 'both'),
#  ('Nichibutsu', 1995, Decimal('0.28'), 'both'),
#  ('Nihon Falcom Corporation', 2012, Decimal('0.43'), 'best'),
#  ('Nihon Falcom Corporation', 2014, Decimal('0.06'), 'worst'),
#  ('Nintendo', 2006, Decimal('205.61'), 'best'),
#  ('Nintendo', 2016, Decimal('3.47'), 'worst'),
#  ('Nippon Amuse', 2002, Decimal('0.09'), 'both'),
#  ('Nippon Columbia', 2012, Decimal('0.28'), 'best'),
#  ('Nippon Columbia', 2016, Decimal('0.06'), 'worst'),
#  ('Nippon Ichi Software', 2013, Decimal('3.47'), 'best'),
#  ('Nippon Ichi Software', 1998, Decimal('0.04'), 'worst'),
#  ('Nippon Telenet', 1996, Decimal('0.26'), 'both'),
#  ('Nitroplus', 2014, Decimal('0.01'), 'both'),
#  ('Nitroplus', 2015, Decimal('0.01'), 'both'),
#  ('Nobilis', 2007, Decimal('0.06'), 'worst'),
#  ('Nobilis', 2008, Decimal('1.65'), 'best'),
#  ('Nordcurrent', 2009, Decimal('0.23'), 'best'),
#  ('Nordcurrent', 2007, Decimal('0.05'), 'worst'),
#  ('Nordic Games', 2016, Decimal('0.03'), 'worst'),
#  ('Nordic Games', 2009, Decimal('1.24'), 'best'),
#  ('NovaLogic', 2009, Decimal('0.02'), 'worst'),
#  ('NovaLogic', 2005, Decimal('0.80'), 'best'),
#  ('Number None', 2009, Decimal('0.03'), 'both'),
#  ('O-Games', 2009, Decimal('0.02'), 'worst'),
#  ('O-Games', 2010, Decimal('0.79'), 'best'),
#  ('O3 Entertainment', 2006, Decimal('0.02'), 'worst'),
#  ('O3 Entertainment', 2007, Decimal('0.11'), 'best'),
#  ('Ocean', 1997, Decimal('1.65'), 'best'),
#  ('Ocean', 1996, Decimal('0.13'), 'worst'),
#  ('Office Create', 2013, Decimal('0.03'), 'both'),
#  ('Office Create', 2014, Decimal('0.03'), 'both'),
#  ('On Demand', 1997, Decimal('0.21'), 'both'),
#  ('Ongakukan', 2006, Decimal('0.01'), 'both'),
#  ('Origin Systems', 1997, Decimal('0.09'), 'both'),
#  ('Otomate', 2013, Decimal('0.01'), 'both'),
#  ('Oxygen Interactive', 2006, Decimal('1.80'), 'best'),
#  ('Oxygen Interactive', 2007, Decimal('0.14'), 'worst'),
#  ('P2 Games', 2009, Decimal('0.08'), 'worst'),
#  ('P2 Games', 2011, Decimal('0.32'), 'best'),
#  ('Pacific Century Cyber Works', 2002, Decimal('0.26'), 'both'),
#  ('Pack In Soft', 1999, Decimal('0.48'), 'both'),
#  ('Pack-In-Video', 1995, Decimal('0.11'), 'both'),
#  ('Palcom', 1989, Decimal('4.17'), 'both'),
#  ('Panther Software', 1995, Decimal('0.17'), 'both'),
#  ('Paon', 2007, Decimal('0.14'), 'best'),
#  ('Paon', 2010, Decimal('0.02'), 'worst'),
#  ('Paon', 2011, Decimal('0.02'), 'worst'),
#  ('Paon Corporation', 2013, Decimal('0.03'), 'both'),
#  ('Paradox Development', 2016, Decimal('0.01'), 'both'),
#  ('Paradox Interactive', 2012, Decimal('0.02'), 'worst'),
#  ('Paradox Interactive', 2011, Decimal('0.18'), 'best'),
#  ('Paradox Interactive', 2014, Decimal('0.02'), 'worst'),
#  ('Parker Bros.', 1983, Decimal('0.50'), 'worst'),
#  ('Parker Bros.', 1981, Decimal('3.35'), 'best'),
#  ('Performance Designed Products', 2009, Decimal('0.36'), 'both'),
#  ('Phantagram', 2002, Decimal('0.05'), 'both'),
#  ('Phantom EFX', 2009, Decimal('0.09'), 'both'),
#  ('Phenomedia', 2007, Decimal('0.11'), 'best'),
#  ('Phenomedia', 2008, Decimal('0.03'), 'worst'),
#  ('Phoenix Games', 2007, Decimal('0.02'), 'both'),
#  ('Piacci', 2010, Decimal('0.01'), 'both'),
#  ('Pinnacle', 2008, Decimal('1.04'), 'best'),
#  ('Pinnacle', 2009, Decimal('0.38'), 'worst'),
#  ('Pioneer LDC', 1996, Decimal('0.62'), 'best'),
#  ('Pioneer LDC', 2001, Decimal('0.05'), 'worst'),
#  ('Play It', 2004, Decimal('2.42'), 'best'),
#  ('Play It', 2003, Decimal('0.31'), 'worst'),
#  ('Playlogic Game Factory', 2009, Decimal('0.86'), 'best'),
#  ('Playlogic Game Factory', 2005, Decimal('0.12'), 'worst'),
#  ('Playmates', 1997, Decimal('0.28'), 'both'),
#  ('Playmore', 2002, Decimal('0.04'), 'both'),
#  ('PlayV', 2009, Decimal('0.02'), 'worst'),
#  ('PlayV', 2010, Decimal('0.42'), 'best'),
#  ('Plenty', 2011, Decimal('0.02'), 'both'),
#  ('PM Studios', 2009, Decimal('0.10'), 'both'),
#  ('Pony Canyon', 2000, Decimal('0.05'), 'both'),
#  ('PopCap Games', 2009, Decimal('0.54'), 'best'),
#  ('PopCap Games', 2006, Decimal('0.01'), 'worst'),
#  ('Popcorn Arcade', 2008, Decimal('0.24'), 'worst'),
#  ('Popcorn Arcade', 2007, Decimal('0.25'), 'best'),
#  ('PopTop Software', 1999, Decimal('0.11'), 'both'),
#  ('Pow', 1995, Decimal('0.05'), 'both'),
#  ('PQube', 2009, Decimal('1.07'), 'best'),
#  ('PQube', 2012, Decimal('0.08'), 'worst'),
#  ('Princess Soft', 2008, Decimal('0.02'), 'worst'),
#  ('Princess Soft', 2006, Decimal('0.03'), 'best'),
#  ('Princess Soft', 2002, Decimal('0.02'), 'worst'),
#  ('Prototype', 2013, Decimal('0.01'), 'worst'),
#  ('Prototype', 2009, Decimal('0.13'), 'best'),
#  ('Prototype', 2016, Decimal('0.01'), 'worst'),
#  ('Psygnosis', 1994, Decimal('0.06'), 'worst'),
#  ('Psygnosis', 1996, Decimal('2.32'), 'best'),
#  ('Quelle', 1982, Decimal('0.87'), 'both'),
#  ('Quest', 1995, Decimal('0.71'), 'both'),
#  ('Quinrose', 2014, Decimal('0.02'), 'worst'),
#  ('Quinrose', 2013, Decimal('0.02'), 'worst'),
#  ('Quinrose', 2011, Decimal('0.12'), 'best'),
#  ('Quintet', 1998, Decimal('0.02'), 'both'),
#  ('Rage Software', 2001, Decimal('0.14'), 'worst'),
#  ('Rage Software', 2002, Decimal('1.28'), 'best'),
#  ('Rain Games', 2015, Decimal('0.01'), 'both'),
#  ('Rebellion', 2002, Decimal('0.01'), 'worst'),
#  ('Rebellion', 2001, Decimal('0.48'), 'best'),
#  ('Rebellion Developments', 2015, Decimal('0.30'), 'both'),
#  ('RED Entertainment', 2010, Decimal('0.02'), 'both'),
#  ('Red Orb', 1997, Decimal('2.43'), 'worst'),
#  ('Red Orb', 1994, Decimal('2.81'), 'best'),
#  ('Red Storm Entertainment', 1999, Decimal('2.28'), 'best'),
#  ('Red Storm Entertainment', 2001, Decimal('0.04'), 'worst'),
#  ('RedOctane', 2007, Decimal('1.11'), 'worst'),
#  ('RedOctane', 2006, Decimal('5.12'), 'best'),
#  ('Reef Entertainment', 2009, Decimal('0.12'), 'best'),
#  ('Reef Entertainment', 2010, Decimal('0.12'), 'best'),
#  ('Reef Entertainment', 2012, Decimal('0.10'), 'worst'),
#  ('responDESIGN', 2004, Decimal('0.09'), 'best'),
#  ('responDESIGN', 2005, Decimal('0.04'), 'worst'),
#  ('Revolution (Japan)', 2009, Decimal('0.02'), 'both'),
#  ('Revolution Software', 2015, Decimal('0.07'), 'both'),
#  ('Rising Star Games', 2016, Decimal('0.02'), 'worst'),
#  ('Rising Star Games', 2007, Decimal('4.88'), 'best'),
#  ('Riverhillsoft', 1995, Decimal('0.04'), 'both'),
#  ('Rocket Company', 2008, Decimal('0.01'), 'worst'),
#  ('Rocket Company', 2006, Decimal('0.69'), 'best'),
#  ('Rondomedia', 2015, Decimal('0.03'), 'worst'),
#  ('Rondomedia', 2009, Decimal('1.54'), 'best'),
#  ('RTL', 2007, Decimal('1.26'), 'best'),
#  ('RTL', 2009, Decimal('0.08'), 'worst'),
#  ('Russel', 2007, Decimal('1.12'), 'best'),
#  ('Russel', 2008, Decimal('0.01'), 'worst'),
#  ('Sammy Corporation', 2006, Decimal('0.08'), 'worst'),
#  ('Sammy Corporation', 2004, Decimal('1.00'), 'best'),
#  ('Saurus', 1998, Decimal('0.02'), 'both'),
#  ('Scholastic Inc.', 2008, Decimal('1.06'), 'best'),
#  ('Scholastic Inc.', 2011, Decimal('0.44'), 'worst'),
#  ('SCi', 2003, Decimal('1.52'), 'best'),
#  ('SCi', 2005, Decimal('0.27'), 'worst'),
#  ('Screenlife', 2013, Decimal('0.83'), 'best'),
#  ('Screenlife', 2016, Decimal('0.02'), 'worst'),
#  ('SCS Software', 2012, Decimal('0.13'), 'both'),
#  ('Sega', 2017, Decimal('0.04'), 'worst'),
#  ('Sega', 2008, Decimal('37.19'), 'best'),
#  ('Seta Corporation', 1996, Decimal('0.30'), 'worst'),
#  ('Seta Corporation', 1995, Decimal('0.33'), 'best'),
#  ('Seventh Chord', 2013, Decimal('0.08'), 'both'),
#  ('Shogakukan', 2015, Decimal('0.03'), 'worst'),
#  ('Shogakukan', 2006, Decimal('0.20'), 'best'),
#  ('Simon & Schuster Interactive', 2002, Decimal('0.11'), 'both'),
#  ('Slightly Mad Studios', 2015, Decimal('1.38'), 'both'),
#  ('Slitherine Software', 2010, Decimal('0.13'), 'best'),
#  ('Slitherine Software', 2009, Decimal('0.03'), 'worst'),
#  ('SNK', 2005, Decimal('0.07'), 'worst'),
#  ('SNK', 1994, Decimal('0.80'), 'best'),
#  ('SNK Playmore', 1995, Decimal('0.28'), 'best'),
#  ('SNK Playmore', 2006, Decimal('0.02'), 'worst'),
#  ('Societa', 1996, Decimal('0.04'), 'both'),
#  ('Sold Out', 2016, Decimal('0.02'), 'both'),
#  ('Sonnet', 1996, Decimal('0.02'), 'worst'),
#  ('Sonnet', 1995, Decimal('0.04'), 'best'),
#  ('Sony Computer Entertainment', 1997, Decimal('43.90'), 'best'),
#  ('Sony Computer Entertainment', 1994, Decimal('3.43'), 'worst'),
#  ('Sony Computer Entertainment America', 2014, Decimal('1.18'), 'both'),
#  ('Sony Computer Entertainment Europe', 2012, Decimal('0.25'), 'worst'),
#  ('Sony Computer Entertainment Europe', 2013, Decimal('10.52'), 'best'),
#  ('Sony Music Entertainment', 2001, Decimal('0.14'), 'both'),
#  ('Sony Online Entertainment', 2004, Decimal('1.28'), 'best'),
#  ('Sony Online Entertainment', 2006, Decimal('0.16'), 'worst'),
#  ('SouthPeak Games', 2009, Decimal('1.97'), 'best'),
#  ('SouthPeak Games', 1999, Decimal('0.11'), 'worst'),
#  ('Spike', 2007, Decimal('1.92'), 'best'),
#  ('Spike', 2004, Decimal('0.08'), 'worst'),
#  ('SPS', 1996, Decimal('0.12'), 'both'),
#  ('Square', 1994, Decimal('0.11'), 'worst'),
#  ('Square', 1991, Decimal('1.77'), 'best'),
#  ('Square EA', 1999, Decimal('0.80'), 'both'),
#  ('Square Enix', 2003, Decimal('2.42'), 'worst'),
#  ('Square Enix', 2010, Decimal('17.44'), 'best'),
#  ('SquareSoft', 1999, Decimal('13.52'), 'best'),
#  ('SquareSoft', 2002, Decimal('0.12'), 'worst'),
#  ('SSI', 1996, Decimal('0.19'), 'both'),
#  ('Stainless Games', 2016, Decimal('0.01'), 'both'),
#  ('Starfish', 1997, Decimal('0.36'), 'best'),
#  ('Starfish', 2010, Decimal('0.02'), 'worst'),
#  ('Starfish', 2009, Decimal('0.02'), 'worst'),
#  ('Starfish', 2012, Decimal('0.02'), 'worst'),
#  ('Starpath Corp.', 1981, Decimal('0.33'), 'both'),
#  ('Sting', 2008, Decimal('0.38'), 'best'),
#  ('Sting', 2010, Decimal('0.03'), 'worst'),
#  ('Sting', 2006, Decimal('0.03'), 'worst'),
#  ('Storm City Games', 2011, Decimal('0.09'), 'worst'),
#  ('Storm City Games', 2010, Decimal('1.11'), 'best'),
#  ('Strategy First', 2001, Decimal('0.03'), 'both'),
#  ('Success', 2009, Decimal('0.01'), 'worst'),
#  ('Success', 2000, Decimal('0.01'), 'worst'),
#  ('Success', 1998, Decimal('1.15'), 'best'),
#  ('Success', 2014, Decimal('0.01'), 'worst'),
#  ('Summitsoft', 2004, Decimal('0.04'), 'both'),
#  ('Sunflowers', 2004, Decimal('0.03'), 'both'),
#  ('Sunrise Interactive', 2006, Decimal('0.02'), 'worst'),
#  ('Sunrise Interactive', 2000, Decimal('0.13'), 'best'),
#  ('Sunrise Interactive', 2007, Decimal('0.02'), 'worst'),
#  ('Sunsoft', 2000, Decimal('0.25'), 'best'),
#  ('Sunsoft', 1995, Decimal('0.03'), 'worst'),
#  ('Sweets', 2006, Decimal('0.02'), 'worst'),
#  ('Sweets', 2009, Decimal('0.03'), 'best'),
#  ('Swing! Entertainment', 2000, Decimal('0.18'), 'best'),
#  ('Swing! Entertainment', 1998, Decimal('0.05'), 'worst'),
#  ('Syscom', 1999, Decimal('0.11'), 'worst'),
#  ('Syscom', 1998, Decimal('0.16'), 'best'),
#  ('System 3', 2013, Decimal('0.22'), 'both'),
#  ('System 3 Arcade Software', 2008, Decimal('1.33'), 'best'),
#  ('System 3 Arcade Software', 2009, Decimal('0.06'), 'worst'),
#  ('System Soft', 2008, Decimal('0.02'), 'best'),
#  ('System Soft', 2010, Decimal('0.02'), 'best'),
#  ('System Soft', 2011, Decimal('0.01'), 'worst'),
#  ('T&E Soft', 1993, Decimal('0.12'), 'both'),
#  ('Taito', 2003, Decimal('0.01'), 'worst'),
#  ('Taito', 1997, Decimal('1.09'), 'best'),
#  ('Takara', 1994, Decimal('0.96'), 'best'),
#  ('Takara', 2003, Decimal('0.04'), 'worst'),
#  ('Takara', 2002, Decimal('0.04'), 'worst'),
#  ('Takara Tomy', 2011, Decimal('0.02'), 'worst'),
#  ('Takara Tomy', 2008, Decimal('1.05'), 'best'),
#  ('Take-Two Interactive', 1999, Decimal('1.68'), 'worst'),
#  ('Take-Two Interactive', 2013, Decimal('52.41'), 'best'),
#  ('Takuyo', 2011, Decimal('0.01'), 'both'),
#  ('TalonSoft', 2001, Decimal('0.87'), 'both'),
#  ('TDK Core', 2006, Decimal('0.22'), 'best'),
#  ('TDK Core', 2007, Decimal('0.03'), 'worst'),
#  ('TDK Mediactive', 2002, Decimal('3.48'), 'best'),
#  ('TDK Mediactive', 2001, Decimal('0.75'), 'worst'),
#  ('Team17 Software', 2010, Decimal('0.05'), 'both'),
#  ('Technos Japan Corporation', 1995, Decimal('0.02'), 'both'),
#  ('TechnoSoft', 1998, Decimal('0.05'), 'both'),
#  ('Tecmo Koei', 2007, Decimal('5.58'), 'best'),
#  ('Tecmo Koei', 1992, Decimal('0.29'), 'worst'),
#  ('Telegames', 2005, Decimal('0.02'), 'worst'),
#  ('Telegames', 2007, Decimal('0.54'), 'best'),
#  ('Telegames', 1999, Decimal('0.02'), 'worst'),
#  ('Telltale Games', 2011, Decimal('0.19'), 'worst'),
#  ('Telltale Games', 2014, Decimal('1.93'), 'best'),
#  ('Telstar', 1998, Decimal('0.21'), 'best'),
#  ('Telstar', 1995, Decimal('0.06'), 'worst'),
#  ('Tetris Online', 2011, Decimal('0.43'), 'both'),
#  ('TGL', 2009, Decimal('0.01'), 'worst'),
#  ('TGL', 2015, Decimal('0.09'), 'best'),
#  ('The Adventure Company', 2009, Decimal('0.26'), 'best'),
#  ('The Adventure Company', 2008, Decimal('0.25'), 'worst'),
#  ('The Learning Company', 2000, Decimal('0.05'), 'both'),
#  ('THQ', 2013, Decimal('0.36'), 'worst'),
#  ('THQ', 2007, Decimal('33.29'), 'best'),
#  ('Tigervision', 1982, Decimal('0.28'), 'worst'),
#  ('Tigervision', 1981, Decimal('1.14'), 'best'),
#  ('Time Warner Interactive', 1996, Decimal('0.16'), 'best'),
#  ('Time Warner Interactive', 1995, Decimal('0.08'), 'worst'),
#  ('Titus', 2001, Decimal('0.99'), 'best'),
#  ('Titus', 2003, Decimal('0.02'), 'worst'),
#  ('Tivola', 2008, Decimal('0.05'), 'worst'),
#  ('Tivola', 2009, Decimal('0.12'), 'best'),
#  ('TOHO', 1993, Decimal('0.11'), 'both'),
#  ('Tommo', 2009, Decimal('0.02'), 'worst'),
#  ('Tommo', 2007, Decimal('0.15'), 'best'),
#  ('Tomy Corporation', 2003, Decimal('1.34'), 'best'),
#  ('Tomy Corporation', 2006, Decimal('0.02'), 'worst'),
#  ('TopWare Interactive', 2011, Decimal('0.03'), 'best'),
#  ('TopWare Interactive', 2015, Decimal('0.01'), 'worst'),
#  ('Touchstone', 2007, Decimal('0.14'), 'worst'),
#  ('Touchstone', 2008, Decimal('1.44'), 'best'),
#  ('Tradewest', 2010, Decimal('0.11'), 'both'),
#  ('Trion Worlds', 2012, Decimal('0.01'), 'worst'),
#  ('Trion Worlds', 2013, Decimal('1.14'), 'best'),
#  ('Tripwire Interactive', 2011, Decimal('0.14'), 'both'),
#  ('Tru Blu Entertainment', 2014, Decimal('0.03'), 'worst'),
#  ('Tru Blu Entertainment', 2015, Decimal('0.25'), 'best'),
#  ('Tryfirst', 2008, Decimal('0.03'), 'both'),
#  ('TYO', 1998, Decimal('0.42'), 'both'),
#  ('Type-Moon', 2014, Decimal('0.10'), 'both'),
#  ('U.S. Gold', 1996, Decimal('0.15'), 'worst'),
#  ('U.S. Gold', 1995, Decimal('0.18'), 'best'),
#  ('Ubisoft', 1996, Decimal('0.16'), 'worst'),
#  ('Ubisoft', 2008, Decimal('57.44'), 'best'),
#  ('Ubisoft Annecy', 2012, Decimal('0.67'), 'worst'),
#  ('Ubisoft Annecy', 2009, Decimal('1.43'), 'best'),
#  ('UEP Systems', 1997, Decimal('2.25'), 'both'),
#  ('UFO Interactive', 2010, Decimal('0.56'), 'best'),
#  ('UFO Interactive', 2012, Decimal('0.01'), 'worst'),
#  ('UIG Entertainment', 2016, Decimal('0.01'), 'both'),
#  ('Universal Gamex', 1982, Decimal('0.63'), 'both'),
#  ('Universal Interactive', 2003, Decimal('2.93'), 'worst'),
#  ('Universal Interactive', 2002, Decimal('8.75'), 'best'),
#  ('Unknown', 2009, Decimal('0.02'), 'worst'),
#  ('Unknown', 2011, Decimal('4.79'), 'best'),
#  ('Valcon Games', 2010, Decimal('0.01'), 'worst'),
#  ('Valcon Games', 2009, Decimal('0.16'), 'best'),
#  ('ValuSoft', 2005, Decimal('0.24'), 'best'),
#  ('ValuSoft', 2011, Decimal('0.01'), 'worst'),
#  ('Valve', 2011, Decimal('1.74'), 'both'),
#  ('Valve Software', 2011, Decimal('2.86'), 'best'),
#  ('Valve Software', 2009, Decimal('0.37'), 'worst'),
#  ('Vap', 1994, Decimal('0.05'), 'both'),
#  ('Vatical Entertainment', 2000, Decimal('0.22'), 'both'),
#  ('Vic Tokai', 1996, Decimal('0.12'), 'worst'),
#  ('Vic Tokai', 1997, Decimal('0.15'), 'best'),
#  ('Victor Interactive', 1997, Decimal('0.23'), 'best'),
#  ('Victor Interactive', 2002, Decimal('0.02'), 'worst'),
#  ('Video System', 2000, Decimal('0.11'), 'worst'),
#  ('Video System', 1998, Decimal('1.60'), 'best'),
#  ('Views', 2014, Decimal('0.01'), 'worst'),
#  ('Views', 2012, Decimal('0.02'), 'best'),
#  ('Vir2L Studios', 2008, Decimal('0.10'), 'worst'),
#  ('Vir2L Studios', 2009, Decimal('0.16'), 'best'),
#  ('Virgin Interactive', 1996, Decimal('14.83'), 'best'),
#  ('Virgin Interactive', 2002, Decimal('0.54'), 'worst'),
#  ('Virtual Play Games', 2010, Decimal('0.06'), 'both'),
#  ('Visco', 2011, Decimal('0.02'), 'both'),
#  ('Vivendi Games', 1995, Decimal('0.02'), 'worst'),
#  ('Vivendi Games', 2003, Decimal('15.43'), 'best'),
#  ('Wanadoo', 2005, Decimal('0.02'), 'worst'),
#  ('Wanadoo', 2002, Decimal('0.46'), 'best'),
#  ('Warashi', 2007, Decimal('0.02'), 'both'),
#  ('Wargaming.net', 2011, Decimal('0.29'), 'both'),
#  ('Warner Bros. Interactive Entertainment', 2005, Decimal('0.06'), 'worst'),
#  ('Warner Bros. Interactive Entertainment', 2015, Decimal('21.74'), 'best'),
#  ('Warp', 1997, Decimal('0.07'), 'both'),
#  ('WayForward Technologies', 2015, Decimal('0.05'), 'both'),
#  ('Westwood Studios', 1999, Decimal('1.55'), 'both'),
#  ('White Park Bay Software', 2007, Decimal('0.16'), 'both'),
#  ('Wizard Video Games', 1982, Decimal('0.62'), 'both'),
#  ('Xicat Interactive', 2002, Decimal('0.14'), 'best'),
#  ('Xicat Interactive', 2003, Decimal('0.03'), 'worst'),
#  ('Xing Entertainment', 1997, Decimal('0.24'), 'both'),
#  ('Xplosiv', 2008, Decimal('0.82'), 'best'),
#  ('Xplosiv', 2005, Decimal('0.20'), 'worst'),
#  ('XS Games', 2009, Decimal('0.71'), 'best'),
#  ('XS Games', 2007, Decimal('0.02'), 'worst'),
#  ('Xseed Games', 2015, Decimal('0.05'), 'worst'),
#  ('Xseed Games', 2012, Decimal('0.55'), 'best'),
#  ('Yacht Club Games', 2015, Decimal('0.32'), 'both'),
#  ('Yamasa Entertainment', 2006, Decimal('0.04'), 'both'),
#  ('Yeti', 2012, Decimal('0.01'), 'worst'),
#  ('Yeti', 2006, Decimal('0.01'), 'worst'),
#  ('Yeti', 2007, Decimal('0.01'), 'worst'),
#  ('Yeti', 2010, Decimal('0.11'), 'best'),
#  ("Yuke's", 2006, Decimal('0.03'), 'best'),
#  ("Yuke's", 2007, Decimal('0.02'), 'worst'),
#  ("Yuke's", 2005, Decimal('0.03'), 'best'),
#  ('Yumedia', 1995, Decimal('0.06'), 'both'),
#  ('Zenrin', 2007, Decimal('0.02'), 'worst'),
#  ('Zenrin', 2006, Decimal('0.04'), 'best'),
#  ('Zoo Digital Publishing', 2005, Decimal('3.19'), 'best'),
#  ('Zoo Digital Publishing', 2002, Decimal('0.37'), 'worst'),
#  ('Zoo Digital Publishing', 2006, Decimal('0.37'), 'worst'),
#  ('Zoo Games', 2009, Decimal('2.43'), 'best'),
#  ('Zoo Games', 2011, Decimal('0.35'), 'worst'),
#  ('Zushi Games', 2009, Decimal('1.28'), 'best'),
#  ('Zushi Games', 2007, Decimal('0.05'), 'worst')]

# %% [markdown]
# ## 9. There are 12 different genres in total. Find the years that do not have all of them. What are those missing genres?

# %%
# %%sql
#
# WITH cte1 AS (SELECT DISTINCT year FROM vgsales),
#      cte2 AS (SELECT DISTINCT genre FROM vgsales),
#      cte3 AS (SELECT year, genre FROM vgsales GROUP BY year, genre)
# SELECT c1.year, c2.genre AS missing_genre
# FROM cte1 c1
# CROSS JOIN cte2 c2
# LEFT JOIN cte3 c3
#     ON c1.year=c3.year AND c2.genre=c3.genre
# WHERE c3.year IS NULL
# ORDER BY 1, 2;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/videogamesalesdb
# 79 rows affected.
# [(1980, 'Adventure'),
#  (1980, 'Platform'),
#  (1980, 'Puzzle'),
#  (1980, 'Racing'),
#  (1980, 'Role-Playing'),
#  (1980, 'Simulation'),
#  (1980, 'Strategy'),
#  (1981, 'Adventure'),
#  (1981, 'Fighting'),
#  (1981, 'Misc'),
#  (1981, 'Role-Playing'),
#  (1981, 'Strategy'),
#  (1982, 'Adventure'),
#  (1982, 'Fighting'),
#  (1982, 'Role-Playing'),
#  (1982, 'Simulation'),
#  (1982, 'Strategy'),
#  (1983, 'Fighting'),
#  (1983, 'Racing'),
#  (1983, 'Role-Playing'),
#  (1983, 'Simulation'),
#  (1983, 'Strategy'),
#  (1984, 'Adventure'),
#  (1984, 'Fighting'),
#  (1984, 'Role-Playing'),
#  (1984, 'Simulation'),
#  (1984, 'Strategy'),
#  (1985, 'Adventure'),
#  (1985, 'Misc'),
#  (1985, 'Racing'),
#  (1985, 'Role-Playing'),
#  (1985, 'Strategy'),
#  (1986, 'Adventure'),
#  (1986, 'Fighting'),
#  (1986, 'Misc'),
#  (1986, 'Puzzle'),
#  (1986, 'Simulation'),
#  (1986, 'Strategy'),
#  (1987, 'Misc'),
#  (1987, 'Puzzle'),
#  (1987, 'Racing'),
#  (1987, 'Simulation'),
#  (1987, 'Strategy'),
#  (1988, 'Adventure'),
#  (1988, 'Fighting'),
#  (1988, 'Misc'),
#  (1988, 'Strategy'),
#  (1989, 'Adventure'),
#  (1989, 'Fighting'),
#  (1989, 'Racing'),
#  (1989, 'Simulation'),
#  (1989, 'Strategy'),
#  (1990, 'Adventure'),
#  (1990, 'Fighting'),
#  (1990, 'Misc'),
#  (1990, 'Shooter'),
#  (1990, 'Strategy'),
#  (2016, 'Puzzle'),
#  (2017, 'Adventure'),
#  (2017, 'Fighting'),
#  (2017, 'Misc'),
#  (2017, 'Platform'),
#  (2017, 'Puzzle'),
#  (2017, 'Racing'),
#  (2017, 'Shooter'),
#  (2017, 'Simulation'),
#  (2017, 'Sports'),
#  (2017, 'Strategy'),
#  (2020, 'Action'),
#  (2020, 'Adventure'),
#  (2020, 'Fighting'),
#  (2020, 'Misc'),
#  (2020, 'Platform'),
#  (2020, 'Puzzle'),
#  (2020, 'Racing'),
#  (2020, 'Role-Playing'),
#  (2020, 'Shooter'),
#  (2020, 'Sports'),
#  (2020, 'Strategy')]

# %% [markdown]
# ## 10. Out of the top 50 best-selling video games, what are the games that were released before 2000?

# %% [markdown]
# As we can see from the query below, some video games were released on one platform first, then on other platforms a few years later (e.g., Super Mario 64 and Grand Theft Auto: San Andreas). In this case, we will consider the earliest year as the year of release.

# %%
# %%sql
#
# SELECT name, platform, year
# FROM vgsales
# WHERE name='Super Mario 64' OR name='Grand Theft Auto: San Andreas'
# ORDER BY name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/videogamesalesdb
# 6 rows affected.
# [('Grand Theft Auto: San Andreas', 'PS2', 2004),
#  ('Grand Theft Auto: San Andreas', 'XB', 2005),
#  ('Grand Theft Auto: San Andreas', 'PC', 2005),
#  ('Grand Theft Auto: San Andreas', 'X360', 2008),
#  ('Super Mario 64', 'N64', 1996),
#  ('Super Mario 64', 'DS', 2004)]

# %%
# %%sql
#
# WITH cte AS (SELECT name
#              FROM vgsales
#              GROUP BY name
#              ORDER BY SUM(global_sales) DESC
#              LIMIT 50)
# SELECT v.name, MIN(v.year) AS release_year
# FROM vgsales v
# JOIN cte c
#     USING (name)
# GROUP BY v.name
# HAVING release_year < 2000
# ORDER BY 2;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/videogamesalesdb
# 10 rows affected.
# [('Duck Hunt', 1984),
#  ('Super Mario Bros.', 1985),
#  ('Tetris', 1988),
#  ('Super Mario Bros. 3', 1988),
#  ('Super Mario Land', 1989),
#  ('Super Mario World', 1990),
#  ('Pokemon Red/Pokemon Blue', 1996),
#  ('Super Mario 64', 1996),
#  ('Pokémon Yellow: Special Pikachu Edition', 1998),
#  ('Pokemon Gold/Pokemon Silver', 1999)]

# %% [markdown]
# &nbsp;

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# Here is a summary of what we've discovered from this analysis:
# - Wii Sports is the best-selling video game globally with 82.74M copies sold, followed by Grand Theft Auto V with 55.92M copies and Super Mario Bros with 45.31M copies.
# - Wii Sports is also the best-selling video game in North America and Europe.
# - The top 3 publishers are Nintendo, Electronic Arts and Activision while the top 3 platforms are PS2, X360 and PS3.
# - The most popular genres are Action with 1.72B copies sold, followed by Sports with 1.31B copies and Shooter with 1.03B copies.
# - The best-selling genre in a single year is Action in 2009 with 139.36M copies sold.
# - Out of the top 50 best-selling video games, only 10 games were released before 2000.
